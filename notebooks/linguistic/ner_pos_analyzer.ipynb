# %% [markdown]
# ## Import

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import time
import os
import argparse
from subprocess import call


import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
tqdm.pandas()

from IPython.display import display, Markdown, Latex, HTML

import torch

from transformers import GPT2Tokenizer
from transformers import AutoModelForSequenceClassification, AutoTokenizer


from verisci.covid import AbstractRetriever, RationaleSelector, LabelPredictor
from verisci.evaluate.lib.data import GoldDataset
#import wandb
# Out:
# /home/qudratealahyratu/anaconda3/envs/scifact/lib/python3.7/site-packages/tqdm/std.py:670: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
loc_df_scispacy_sentence_word_unq_ner_abr_filtered ='../../dfs_generated/linguistic/df_scispacy_sentence_word_unq_ner_abr_filtered.pkl'

# %% [markdown]
# ## Scifact

# %% [markdown]
# ### Load Data

# %%
loc_corpus = '../../data/scifact/corpus.jsonl'
loc_claim_train = '../../data/scifact/claims_train.jsonl'
loc_claim_test = '../../data/scifact/claims_test.jsonl'
loc_claim_dev = '../../data/scifact/claims_dev.jsonl'

# %%
from verisci.evaluate.lib.data import GoldDataset

# %%
def get_claim_label_from_jsonl(dataset_jsonl):
    claim_label_list_train = []


    for cur_claim in dataset_jsonl:
        claim_txt = cur_claim.claim

        for doc_id, evidence in cur_claim.evidence.items():

            ev_doc = cur_claim.release.corpus.get_document(doc_id)

            claim_label = evidence.label.name

            tmp_dic = {"claim" : claim_txt, "label" : claim_label}

            claim_label_list_train.append(tmp_dic)
    return claim_label_list_train

# %%
def get_claim_label_evidence_from_jsonl(dataset_jsonl, source):
    claim_label_list_train = []


    for cur_claim in dataset_jsonl:
        claim_txt = cur_claim.claim

        for doc_id, evidence in cur_claim.evidence.items():

            ev_doc = cur_claim.release.corpus.get_document(doc_id)

            claim_label = evidence.label.name
            
            list_rationales = []
            for i, sents in enumerate(evidence.rationales):
                list_rationales = [sent for i, sent in enumerate(ev_doc.sentences) if i in sents]

            tmp_dic = {"claim" : claim_txt, "label" : claim_label, "list_rationales" :list_rationales, "source" :source}

            claim_label_list_train.append(tmp_dic)
    return claim_label_list_train

# %%
ds_train = GoldDataset(loc_corpus, loc_claim_train)
# claim_train = ds_train.get_claim(39)
# claim_train.pretty_print()
dic_train = get_claim_label_evidence_from_jsonl(ds_train, source = "train")

# %%
ds_valid = GoldDataset(loc_corpus, loc_claim_dev)
# claim_valid = ds_valid.get_claim(42)
# claim_valid.pretty_print()
dic_valid = get_claim_label_evidence_from_jsonl(ds_valid, source = "dev")

# %%
df_claim_evid_label = pd.concat([pd.DataFrame(dic_train), pd.DataFrame(dic_valid)], ignore_index=True)

df_claim_evid_label
# Out:
#                                                  claim     label  \
# 0    1 in 5 million in UK have abnormal PrP positiv...   REFUTES
# 1    32% of liver transplantation programs required...  SUPPORTS
# 2    40mg/day dosage of folic acid and 2mg/day dosa...  SUPPORTS
# 3    76-85% of people with severe mental disorder r...  SUPPORTS
# 4    A T helper 2 cell (Th2) environment impedes di...   REFUTES
# ..                                                 ...       ...
# 768  Women with a higher birth weight are more like...  SUPPORTS
# 769  Women with a higher birth weight are more like...  SUPPORTS
# 770  aPKCz causes tumour enhancement by affecting g...   REFUTES
# 771   cSMAC formation enhances weak ligand signalling.  SUPPORTS
# 772  mTORC2 regulates intracellular cysteine levels...  SUPPORTS
#
#                                        list_rationales source
# 0    [RESULTS Of the 32,441 appendix samples 16 wer...  train
# 1    [Policies requiring discontinuation of methado...  train
# 2    [CONCLUSION Treatment with high doses of folic...  train
# 3    [Although disorder severity was correlated wit...  train
# 4    [Thus, in Lyn(-/-) mice, basophils and IgE aut...  train
# ..                                                 ...    ...
# 768  [Increased risk of breast cancer was noted wit...    dev
# 769  [RESULTS We found that heavier birth weights w...    dev
# 770  [Taken together, this demonstrates that PKCζ i...    dev
# 771  [This conclusion was supported by experiments ...    dev
# 772  [mTORC2 phosphorylates serine 26 at the cytoso...    dev
#
# [773 rows x 4 columns]

# %% [markdown]
# ## Abbreviations

# %%
import spacy

# nlp = spacy.load("en_core_web_trf")

from spacy import displacy
from nltk import word_tokenize
import nltk

# %%
nlp_sci_brt = spacy.load("en_core_sci_scibert")
nlp_sci_lg = spacy.load("en_core_sci_lg")

#import en_ner_bc5cdr_md
nlp_cr = spacy.load("en_ner_craft_md")
nlp_bc = spacy.load("en_ner_bc5cdr_md")
nlp_bi = spacy.load("en_ner_bionlp13cg_md")
nlp_jn = spacy.load("en_ner_jnlpba_md")

nlp_core_web_trf = spacy.load("en_core_web_trf")

# %%
from scispacy.abbreviation import AbbreviationDetector

# %%
nlp_sci_brt.add_pipe("abbreviation_detector")
nlp_sci_lg.add_pipe("abbreviation_detector")
nlp_cr.add_pipe("abbreviation_detector")
nlp_bc.add_pipe("abbreviation_detector")
nlp_bi.add_pipe("abbreviation_detector")
nlp_jn.add_pipe("abbreviation_detector")

# %%
list_sci_brt = set()
list_sci_lg  = set()
list_cr = set()
list_bc = set()
list_bi = set()
list_jn = set()

# %%
list_jn.difference(list_jn)
# Out:
# set()

# %%
list_jn.difference(list_sci_brt)
# Out:
# set()

# %%
list_jn.difference(list_sci_brt.union(list_sci_lg, list_cr, list_bc, list_bi))
# Out:
# set()

# %%
all_sentence_abbr = []
for cur_indx, cur_row in tqdm(df_claim_evid_label.iterrows(), total = len(df_claim_evid_label["claim"])):
    
    cur_claim = cur_row['claim']
    doc_sci_brt = nlp_sci_brt(cur_claim)
    
    doc_sci_lg = nlp_sci_lg(cur_claim)
    
    doc_cr = nlp_cr(cur_claim)
    
    
    doc_bc = nlp_bc(cur_claim)
    
    doc_bi = nlp_bi(cur_claim)
    
    doc_jn = nlp_jn(cur_claim)
    
    
    
    
    
    cur_all_abbr = {}
    
    for cur_abr in doc_sci_brt._.abbreviations:  
        list_sci_brt.add(str(cur_abr))
        
        cur_all_abbr[str(cur_abr)] = {'abrv_text': str(cur_abr), 'abr_definition' : str(cur_abr._.long_form), 
                                      'abr_model' : 'en_core_sci_scibert', 'claim' : cur_claim, 'sf_start_char' : cur_abr.start_char, 'sf_end_char' : cur_abr.end_char,
                                     'lf_start_char' : cur_abr._.long_form.start_char, 'lf_end_char' : cur_abr._.long_form.end_char, 
                                     'org_label' : cur_row['label'], 'list_rationales' : cur_row['list_rationales'],
                                      'data_source' : cur_row['source']}
        cur_all_abbr[str(cur_abr)]['abr_whole_start'] = -1
        cur_all_abbr[str(cur_abr)]['abr_whole_end'] = -1
        # if short and long form of abbraviation exists
        if((cur_abr.end_char - cur_abr.start_char > 0) & (cur_abr._.long_form.end_char - cur_abr._.long_form.start_char > 0)):
            # Aaa Bbb Rrr (ABR) or ABR (Aaa Bbb Rrr)  
            if (cur_abr.start_char - cur_abr._.long_form.end_char   < 4 )| (cur_abr._.long_form.start_char - cur_abr.end_char < 4):
                cur_all_abbr[str(cur_abr)]['abr_whole_start'] = min(cur_abr.start_char, cur_abr._.long_form.start_char)
                cur_all_abbr[str(cur_abr)]['abr_whole_end'] = max(cur_abr.end_char, cur_abr._.long_form.end_char)
    
    for cur_abr in doc_sci_lg._.abbreviations:  
        list_sci_lg.add(str(cur_abr))
        cur_all_abbr[str(cur_abr)] = {'abrv_text': str(cur_abr), 'abr_definition' : str(cur_abr._.long_form), 
                                      'abr_model' : 'en_core_sci_lg', 'claim' : cur_claim, 'sf_start_char' : cur_abr.start_char, 'sf_end_char' : cur_abr.end_char,
                                     'lf_start_char' : cur_abr._.long_form.start_char, 'lf_end_char' : cur_abr._.long_form.end_char, 
                                     'org_label' : cur_row['label'], 'list_rationales' : cur_row['list_rationales'],
                                      'data_source' : cur_row['source']}
        
        cur_all_abbr[str(cur_abr)]['abr_whole_start'] = -1
        cur_all_abbr[str(cur_abr)]['abr_whole_end'] = -1
        # if short and long form of abbraviation exists
        if((cur_abr.end_char - cur_abr.start_char > 0) & (cur_abr._.long_form.end_char - cur_abr._.long_form.start_char > 0)):
            # Aaa Bbb Rrr (ABR) or ABR (Aaa Bbb Rrr)  
            if (cur_abr.start_char - cur_abr._.long_form.end_char   < 4 )| (cur_abr._.long_form.start_char - cur_abr.end_char < 4):
                cur_all_abbr[str(cur_abr)]['abr_whole_start'] = min(cur_abr.start_char, cur_abr._.long_form.start_char)
                cur_all_abbr[str(cur_abr)]['abr_whole_end'] = max(cur_abr.end_char, cur_abr._.long_form.end_char)
                
                
    for cur_abr in doc_cr._.abbreviations:  
        list_cr.add(str(cur_abr))
        cur_all_abbr[str(cur_abr)] = {'abrv_text': str(cur_abr), 'abr_definition' : str(cur_abr._.long_form), 
                                      'abr_model' : 'en_ner_craft_md', 'claim' : cur_claim, 'sf_start_char' : cur_abr.start_char, 'sf_end_char' : cur_abr.end_char,
                                      'lf_start_char' : cur_abr._.long_form.start_char, 'lf_end_char' : cur_abr._.long_form.end_char, 
                                      'org_label' : cur_row['label'], 'list_rationales' : cur_row['list_rationales'],
                                      'data_source' : cur_row['source']}
    
    
        cur_all_abbr[str(cur_abr)]['abr_whole_start'] = -1
        cur_all_abbr[str(cur_abr)]['abr_whole_end'] = -1
        # if short and long form of abbraviation exists
        if((cur_abr.end_char - cur_abr.start_char > 0) & (cur_abr._.long_form.end_char - cur_abr._.long_form.start_char > 0)):
            # Aaa Bbb Rrr (ABR) or ABR (Aaa Bbb Rrr)  
            if (cur_abr.start_char - cur_abr._.long_form.end_char   < 4 )| (cur_abr._.long_form.start_char - cur_abr.end_char < 4):
                cur_all_abbr[str(cur_abr)]['abr_whole_start'] = min(cur_abr.start_char, cur_abr._.long_form.start_char)
                cur_all_abbr[str(cur_abr)]['abr_whole_end'] = max(cur_abr.end_char, cur_abr._.long_form.end_char)
                
                
    for cur_abr in doc_bc._.abbreviations:
        list_bc.add(str(cur_abr))
        cur_all_abbr[str(cur_abr)] = {'abrv_text': str(cur_abr), 'abr_definition' : str(cur_abr._.long_form), 
                                      'abr_model' : 'en_ner_bc5cdr_md', 'claim' : cur_claim, 'sf_start_char' : cur_abr.start_char, 'sf_end_char' : cur_abr.end_char,
                                     'lf_start_char' : cur_abr._.long_form.start_char, 'lf_end_char' : cur_abr._.long_form.end_char, 
                                     'org_label' : cur_row['label'], 'list_rationales' : cur_row['list_rationales'],
                                      'data_source' : cur_row['source']}
        
        
        cur_all_abbr[str(cur_abr)]['abr_whole_start'] = -1
        cur_all_abbr[str(cur_abr)]['abr_whole_end'] = -1
        # if short and long form of abbraviation exists
        if((cur_abr.end_char - cur_abr.start_char > 0) & (cur_abr._.long_form.end_char - cur_abr._.long_form.start_char > 0)):
            # Aaa Bbb Rrr (ABR) or ABR (Aaa Bbb Rrr)  
            if (cur_abr.start_char - cur_abr._.long_form.end_char   < 4 )| (cur_abr._.long_form.start_char - cur_abr.end_char < 4):
                cur_all_abbr[str(cur_abr)]['abr_whole_start'] = min(cur_abr.start_char, cur_abr._.long_form.start_char)
                cur_all_abbr[str(cur_abr)]['abr_whole_end'] = max(cur_abr.end_char, cur_abr._.long_form.end_char)
                
                
    for cur_abr in doc_bi._.abbreviations:
        list_bi.add(str(cur_abr))
        cur_all_abbr[str(cur_abr)] = {'abrv_text': str(cur_abr), 'abr_definition' : str(cur_abr._.long_form), 
                                      'abr_model' : 'en_ner_bionlp13cg_md', 'claim' : cur_claim, 'sf_start_char' : cur_abr.start_char, 'sf_end_char' : cur_abr.end_char,
                                     'lf_start_char' : cur_abr._.long_form.start_char, 'lf_end_char' : cur_abr._.long_form.end_char, 
                                     'org_label' : cur_row['label'], 'list_rationales' : cur_row['list_rationales'],
                                      'data_source' : cur_row['source']}
    
    
        cur_all_abbr[str(cur_abr)]['abr_whole_start'] = -1
        cur_all_abbr[str(cur_abr)]['abr_whole_end'] = -1
        # if short and long form of abbraviation exists
        if((cur_abr.end_char - cur_abr.start_char > 0) & (cur_abr._.long_form.end_char - cur_abr._.long_form.start_char > 0)):
            # Aaa Bbb Rrr (ABR) or ABR (Aaa Bbb Rrr)  
            if (cur_abr.start_char - cur_abr._.long_form.end_char   < 4 )| (cur_abr._.long_form.start_char - cur_abr.end_char < 4):
                cur_all_abbr[str(cur_abr)]['abr_whole_start'] = min(cur_abr.start_char, cur_abr._.long_form.start_char)
                cur_all_abbr[str(cur_abr)]['abr_whole_end'] = max(cur_abr.end_char, cur_abr._.long_form.end_char)
                
                
    for cur_abr in doc_jn._.abbreviations:
        list_jn.add(str(cur_abr))
        cur_all_abbr[str(cur_abr)] = {'abrv_text': str(cur_abr), 'abr_definition' : str(cur_abr._.long_form), 
                                      'abr_model' : 'en_ner_jnlpba_md', 'claim' : cur_claim, 'sf_start_char' : cur_abr.start_char, 'sf_end_char' : cur_abr.end_char,
                                     'lf_start_char' : cur_abr._.long_form.start_char, 'lf_end_char' : cur_abr._.long_form.end_char, 
                                     'org_label' : cur_row['label'], 'list_rationales' : cur_row['list_rationales'],
                                      'data_source' : cur_row['source']}
        
        
        cur_all_abbr[str(cur_abr)]['abr_whole_start'] = -1
        cur_all_abbr[str(cur_abr)]['abr_whole_end'] = -1
        # if short and long form of abbraviation exists
        if((cur_abr.end_char - cur_abr.start_char > 0) & (cur_abr._.long_form.end_char - cur_abr._.long_form.start_char > 0)):
            # Aaa Bbb Rrr (ABR) or ABR (Aaa Bbb Rrr)  
            if (cur_abr.start_char - cur_abr._.long_form.end_char   < 4 )| (cur_abr._.long_form.start_char - cur_abr.end_char < 4):
                cur_all_abbr[str(cur_abr)]['abr_whole_start'] = min(cur_abr.start_char, cur_abr._.long_form.start_char)
                cur_all_abbr[str(cur_abr)]['abr_whole_end'] = max(cur_abr.end_char, cur_abr._.long_form.end_char)+1        
    
    
    all_sentence_abbr.extend(list(cur_all_abbr.values()))
    
# en_core_sci_scibert and   en_ner_jnlpba_md having same abbrs
# Out:
# 100%|██████████| 773/773 [01:14<00:00, 10.36it/s]

# %%
all_sentence_abbr
# Out:
# [{'abrv_text': 'CKD',
#   'abr_definition': 'chronic kidney disease',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': '40mg/day dosage of folic acid and 2mg/day dosage of vitamin B12 does not affect chronic kidney disease (CKD) progression.',
#   'sf_start_char': 104,
#   'sf_end_char': 107,
#   'lf_start_char': 80,
#   'lf_end_char': 102,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['CONCLUSION Treatment with high doses of folic acid and B vitamins did not improve survival or reduce the incidence of vascular disease in patients with advanced chronic kidney disease or end-stage renal disease.   \n'],
#   'data_source': 'train',
#   'abr_whole_start': 80,
#   'abr_whole_end': 108},
#  {'abrv_text': 'Th2',
#   'abr_definition': 'T helper 2 cell',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'A T helper 2 cell (Th2) environment impedes disease development in patients with systemic lupus erythematosus (SLE).',
#   'sf_start_char': 19,
#   'sf_end_char': 22,
#   'lf_start_char': 2,
#   'lf_end_char': 17,
#   'org_label': 'REFUTES',
#   'list_rationales': ['Thus, in Lyn(-/-) mice, basophils and IgE autoantibodies amplify autoantibody production that leads to lupus nephritis, and in individuals with SLE IgE autoantibodies and activated basophils are factors associated with disease activity and nephritis.'],
#   'data_source': 'train',
#   'abr_whole_start': 2,
#   'abr_whole_end': 23},
#  {'abrv_text': 'SLE',
#   'abr_definition': 'systemic lupus erythematosus',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'A T helper 2 cell (Th2) environment impedes disease development in patients with systemic lupus erythematosus (SLE).',
#   'sf_start_char': 111,
#   'sf_end_char': 114,
#   'lf_start_char': 81,
#   'lf_end_char': 109,
#   'org_label': 'REFUTES',
#   'list_rationales': ['Thus, in Lyn(-/-) mice, basophils and IgE autoantibodies amplify autoantibody production that leads to lupus nephritis, and in individuals with SLE IgE autoantibodies and activated basophils are factors associated with disease activity and nephritis.'],
#   'data_source': 'train',
#   'abr_whole_start': 81,
#   'abr_whole_end': 115},
#  {'abrv_text': 'AMPK',
#   'abr_definition': 'AMP-activated protein kinase',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'AMP-activated protein kinase (AMPK) activation reduces inflammation-related fibrosis in the lungs.',
#   'sf_start_char': 30,
#   'sf_end_char': 34,
#   'lf_start_char': 0,
#   'lf_end_char': 28,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['These studies implicate deficient AMPK activation in non-resolving, pathologic fibrotic processes, and support a role for metformin (or other AMPK activators) to reverse established fibrosis by facilitating deactivation and apoptosis of myofibroblasts.'],
#   'data_source': 'train',
#   'abr_whole_start': 0,
#   'abr_whole_end': 35},
#  {'abrv_text': 'ESCs',
#   'abr_definition': 'embryonic stem cells',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Androgenetic haploid mouse embryonic stem cells (ESCs) can be derived and genetically manipulated in vitro.',
#   'sf_start_char': 49,
#   'sf_end_char': 53,
#   'lf_start_char': 27,
#   'lf_end_char': 47,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Our results demonstrate that AG-haESCs can be used as a genetically tractable fertilization agent for the production of live animals via injection into oocytes.'],
#   'data_source': 'train',
#   'abr_whole_start': 27,
#   'abr_whole_end': 54},
#  {'abrv_text': 'CSF',
#   'abr_definition': 'cerebrospinal fluid',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Bacterial meningitis can be diagnosed on the basis of positive cerebrospinal fluid (CSF) cultures.',
#   'sf_start_char': 84,
#   'sf_end_char': 87,
#   'lf_start_char': 63,
#   'lf_end_char': 82,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['A CSF-blood glucose ratio of 0.4 or less (likelihood ratio [LR], 18; 95% CI, 12-27]), CSF white blood cell count of 500/muL or higher (LR, 15; 95% CI, 10-22), and CSF lactate level of 31.53 mg/dL or more (> or =3.5 mmol/L; LR, 21; 95% CI, 14-32) accurately diagnosed bacterial meningitis.   \n'],
#   'data_source': 'train',
#   'abr_whole_start': 63,
#   'abr_whole_end': 88},
#  {'abrv_text': 'SLE',
#   'abr_definition': 'systemic lupus erythematosus',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Basophils promote disease development in patients with systemic lupus erythematosus (SLE).',
#   'sf_start_char': 85,
#   'sf_end_char': 88,
#   'lf_start_char': 55,
#   'lf_end_char': 83,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Thus, in Lyn(-/-) mice, basophils and IgE autoantibodies amplify autoantibody production that leads to lupus nephritis, and in individuals with SLE IgE autoantibodies and activated basophils are factors associated with disease activity and nephritis.'],
#   'data_source': 'train',
#   'abr_whole_start': 55,
#   'abr_whole_end': 89},
#  {'abrv_text': 'bnAb',
#   'abr_definition': 'Broadly HIV-1 Neutralizing Antibodies',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Broadly HIV-1 Neutralizing Antibodies (bnAb) 10EB have no affinity for phospholipids.',
#   'sf_start_char': 39,
#   'sf_end_char': 43,
#   'lf_start_char': 0,
#   'lf_end_char': 37,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['In contrast to other neutralizing MPER antibodies, 10E8 did not bind phospholipids, was not autoreactive, and bound cell-surface envelope.'],
#   'data_source': 'train',
#   'abr_whole_start': 0,
#   'abr_whole_end': 44},
#  {'abrv_text': 'ComYMV',
#   'abr_definition': 'Commelina yellow mottle virus',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Commelina yellow mottle virus (ComYMV) has three typical badnavirus ORFs, capable of encoding proteins 23, 15, and 216 kD.',
#   'sf_start_char': 31,
#   'sf_end_char': 37,
#   'lf_start_char': 0,
#   'lf_end_char': 29,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Analysis of the genome sequence indicates that the genome is 7489 bp in size and that the transcribed strand contains three open reading frames capable of encoding proteins of 23, 15 and 216 kd.'],
#   'data_source': 'train',
#   'abr_whole_start': 0,
#   'abr_whole_end': 38},
#  {'abrv_text': 'ComYMV',
#   'abr_definition': "Commelina yellow mottle virus'",
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': "Commelina yellow mottle virus' (ComYMV) genome consists of 2140 baise pairs.",
#   'sf_start_char': 32,
#   'sf_end_char': 38,
#   'lf_start_char': 0,
#   'lf_end_char': 30,
#   'org_label': 'REFUTES',
#   'list_rationales': ['Analysis of the genome sequence indicates that the genome is 7489 bp in size and that the transcribed strand contains three open reading frames capable of encoding proteins of 23, 15 and 216 kd.'],
#   'data_source': 'train',
#   'abr_whole_start': 0,
#   'abr_whole_end': 39},
#  {'abrv_text': 'DBP',
#   'abr_definition': 'diastolic blood pressure',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Decreased diastolic blood pressure (DBP) is associated with abdominal aortic aneurysm.',
#   'sf_start_char': 36,
#   'sf_end_char': 39,
#   'lf_start_char': 10,
#   'lf_end_char': 34,
#   'org_label': 'REFUTES',
#   'list_rationales': ['Compared with diastolic blood pressure, raised systolic blood pressure had a greater effect on angina, myocardial infarction, and peripheral arterial disease, whereas raised diastolic blood pressure had a greater effect on abdominal aortic aneurysm than did raised systolic pressure.'],
#   'data_source': 'train',
#   'abr_whole_start': 10,
#   'abr_whole_end': 40},
#  {'abrv_text': 'Th17',
#   'abr_definition': 'T-helper 17',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Depletion of T-helper 17 (Th17) cells during simian immunodeficiency virus (SIV) infection decreases dissemination of Salmonella Typhimurium from the gut.',
#   'sf_start_char': 26,
#   'sf_end_char': 30,
#   'lf_start_char': 13,
#   'lf_end_char': 24,
#   'org_label': 'REFUTES',
#   'list_rationales': ['TH17 cells were markedly depleted in SIV-infected rhesus macaques, resulting in blunted TH17 responses to S. typhimurium infection and increased bacterial dissemination.'],
#   'data_source': 'train',
#   'abr_whole_start': 13,
#   'abr_whole_end': 31},
#  {'abrv_text': 'SIV',
#   'abr_definition': 'simian immunodeficiency virus',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Depletion of T-helper 17 (Th17) cells during simian immunodeficiency virus (SIV) infection decreases dissemination of Salmonella Typhimurium from the gut.',
#   'sf_start_char': 76,
#   'sf_end_char': 79,
#   'lf_start_char': 45,
#   'lf_end_char': 74,
#   'org_label': 'REFUTES',
#   'list_rationales': ['TH17 cells were markedly depleted in SIV-infected rhesus macaques, resulting in blunted TH17 responses to S. typhimurium infection and increased bacterial dissemination.'],
#   'data_source': 'train',
#   'abr_whole_start': 45,
#   'abr_whole_end': 80},
#  {'abrv_text': 'Th17',
#   'abr_definition': 'T-helper 17',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Depletion of T-helper 17 (Th17) cells during simian immunodeficiency virus (SIV) infection increases dissemination of Salmonella Typhimurium from the gut.',
#   'sf_start_char': 26,
#   'sf_end_char': 30,
#   'lf_start_char': 13,
#   'lf_end_char': 24,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['TH17 cells were markedly depleted in SIV-infected rhesus macaques, resulting in blunted TH17 responses to S. typhimurium infection and increased bacterial dissemination.'],
#   'data_source': 'train',
#   'abr_whole_start': 13,
#   'abr_whole_end': 31},
#  {'abrv_text': 'SIV',
#   'abr_definition': 'simian immunodeficiency virus',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Depletion of T-helper 17 (Th17) cells during simian immunodeficiency virus (SIV) infection increases dissemination of Salmonella Typhimurium from the gut.',
#   'sf_start_char': 76,
#   'sf_end_char': 79,
#   'lf_start_char': 45,
#   'lf_end_char': 74,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['TH17 cells were markedly depleted in SIV-infected rhesus macaques, resulting in blunted TH17 responses to S. typhimurium infection and increased bacterial dissemination.'],
#   'data_source': 'train',
#   'abr_whole_start': 45,
#   'abr_whole_end': 80},
#  {'abrv_text': 'PDA',
#   'abr_definition': 'patent ductus ateriosus',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Early patent ductus ateriosus (PDA) screening decreases in-hospital mortality.',
#   'sf_start_char': 31,
#   'sf_end_char': 34,
#   'lf_start_char': 6,
#   'lf_end_char': 29,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['CONCLUSIONS AND RELEVANCE In this national population-based cohort of extremely preterm infants, screening echocardiography before day 3 of life was associated with lower in-hospital mortality and likelihood of pulmonary hemorrhage but not with differences in necrotizing enterocolitis, severe bronchopulmonary dysplasia, or severe cerebral lesions.'],
#   'data_source': 'train',
#   'abr_whole_start': 6,
#   'abr_whole_end': 35},
#  {'abrv_text': 'PDA',
#   'abr_definition': 'patent ductus ateriosus',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Early patent ductus ateriosus (PDA) screening increases in-hospital mortality.',
#   'sf_start_char': 31,
#   'sf_end_char': 34,
#   'lf_start_char': 6,
#   'lf_end_char': 29,
#   'org_label': 'REFUTES',
#   'list_rationales': ['CONCLUSIONS AND RELEVANCE In this national population-based cohort of extremely preterm infants, screening echocardiography before day 3 of life was associated with lower in-hospital mortality and likelihood of pulmonary hemorrhage but not with differences in necrotizing enterocolitis, severe bronchopulmonary dysplasia, or severe cerebral lesions.'],
#   'data_source': 'train',
#   'abr_whole_start': 6,
#   'abr_whole_end': 35},
#  {'abrv_text': 'EILV',
#   'abr_definition': 'Eilat virus',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Eilat virus (EILV) produced in mosquitos elicits rapid and long-lasting neutralizing antibodies in nonhuman primates.',
#   'sf_start_char': 13,
#   'sf_end_char': 17,
#   'lf_start_char': 0,
#   'lf_end_char': 11,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['A single dose of EILV/CHIKV produced in mosquito cells elicited rapid (within 4 d) and long-lasting (>290 d) neutralizing antibodies that provided complete protection in two different mouse models.',
#    'In nonhuman primates, EILV/CHIKV elicited rapid and robust immunity that protected against viremia and telemetrically monitored fever.'],
#   'data_source': 'train',
#   'abr_whole_start': 0,
#   'abr_whole_end': 18},
#  {'abrv_text': 'APOE4',
#   'abr_definition': 'Apolipoprotein E4',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Female carriers of the Apolipoprotein E4 (APOE4) allele have decreased risk for dementia.',
#   'sf_start_char': 42,
#   'sf_end_char': 47,
#   'lf_start_char': 23,
#   'lf_end_char': 40,
#   'org_label': 'REFUTES',
#   'list_rationales': ['Risk of dementia associated with a longer reproductive period was most pronounced in APOE epsilon4 carriers (adjusted RR for >39 reproductive years compared with <34 reproductive years, 4.20 [95% CI, 1.97-8.92] for dementia and 3.42 [95% CI, 1.51-7.75] for AD), whereas in noncarriers, no clear association with dementia or AD was observed.   \n'],
#   'data_source': 'train',
#   'abr_whole_start': 23,
#   'abr_whole_end': 48},
#  {'abrv_text': 'APOE4',
#   'abr_definition': 'Apolipoprotein E4',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': "Female carriers of the Apolipoprotein E4 (APOE4) allele have increased risk for Alzheimer's disease.",
#   'sf_start_char': 42,
#   'sf_end_char': 47,
#   'lf_start_char': 23,
#   'lf_end_char': 40,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Risk of dementia associated with a longer reproductive period was most pronounced in APOE epsilon4 carriers (adjusted RR for >39 reproductive years compared with <34 reproductive years, 4.20 [95% CI, 1.97-8.92] for dementia and 3.42 [95% CI, 1.51-7.75] for AD), whereas in noncarriers, no clear association with dementia or AD was observed.   \n'],
#   'data_source': 'train',
#   'abr_whole_start': 23,
#   'abr_whole_end': 48},
#  {'abrv_text': 'APOE4',
#   'abr_definition': 'Apolipoprotein E4',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Female carriers of the Apolipoprotein E4 (APOE4) allele have longer lifetime exposure to estrogen due to an increased reproductive period.',
#   'sf_start_char': 42,
#   'sf_end_char': 47,
#   'lf_start_char': 23,
#   'lf_end_char': 40,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Risk of dementia associated with a longer reproductive period was most pronounced in APOE epsilon4 carriers (adjusted RR for >39 reproductive years compared with <34 reproductive years, 4.20 [95% CI, 1.97-8.92] for dementia and 3.42 [95% CI, 1.51-7.75] for AD), whereas in noncarriers, no clear association with dementia or AD was observed.   \n'],
#   'data_source': 'train',
#   'abr_whole_start': 23,
#   'abr_whole_end': 48},
#  {'abrv_text': 'APOE4',
#   'abr_definition': 'Apolipoprotein E4',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Female carriers of the Apolipoprotein E4 (APOE4) allele have shorter lifetime exposure to estrogen due to a decreased reproductive period.',
#   'sf_start_char': 42,
#   'sf_end_char': 47,
#   'lf_start_char': 23,
#   'lf_end_char': 40,
#   'org_label': 'REFUTES',
#   'list_rationales': ['Risk of dementia associated with a longer reproductive period was most pronounced in APOE epsilon4 carriers (adjusted RR for >39 reproductive years compared with <34 reproductive years, 4.20 [95% CI, 1.97-8.92] for dementia and 3.42 [95% CI, 1.51-7.75] for AD), whereas in noncarriers, no clear association with dementia or AD was observed.   \n'],
#   'data_source': 'train',
#   'abr_whole_start': 23,
#   'abr_whole_end': 48},
#  {'abrv_text': 'ROS',
#   'abr_definition': 'reactive oxygen species',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'FoxO3a activation in neuronal death is inhibited by reactive oxygen species (ROS).',
#   'sf_start_char': 77,
#   'sf_end_char': 80,
#   'lf_start_char': 52,
#   'lf_end_char': 75,
#   'org_label': 'REFUTES',
#   'list_rationales': ['Thus, one way in which members of the Sir2 family of proteins may increase organismal longevity is by tipping FOXO-dependent responses away from apoptosis and toward stress resistance.'],
#   'data_source': 'train',
#   'abr_whole_start': 52,
#   'abr_whole_end': 81},
#  {'abrv_text': 'HGPS',
#   'abr_definition': 'Hutchinson-Gilford progeria syndrome',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': "Genomic sequences involved in alternative splicing responsible for Hutchinson-Gilford progeria syndrome (HGPS) are abundant in the ''progerinonly'' allele of Lmna knock-in models.",
#   'sf_start_char': 105,
#   'sf_end_char': 109,
#   'lf_start_char': 67,
#   'lf_end_char': 103,
#   'org_label': 'REFUTES',
#   'list_rationales': ['Hutchinson-Gilford progeria syndrome (HGPS) is a childhood premature aging disease caused by a spontaneous point mutation in lamin A (encoded by LMNA), one of the major architectural elements of the mammalian cell nucleus.',
#    'The mutant LMNA mRNA and lamin A protein can be efficiently eliminated by correction of the aberrant splicing event using a modified oligonucleotide targeted to the activated cryptic splice site.',
#    'Upon splicing correction, HGPS fibroblasts assume normal nuclear morphology, the aberrant nuclear distribution and cellular levels of lamina-associated proteins are rescued, defects in heterochromatin-specific histone modifications are corrected and proper expression of several misregulated genes is reestablished.'],
#   'data_source': 'train',
#   'abr_whole_start': 67,
#   'abr_whole_end': 110},
#  {'abrv_text': 'GBM',
#   'abr_definition': 'Glioblastoma multiforme',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Glioblastoma multiforme (GBM) is characterized by extensive invasion, rapid growth, necrosis, and angiogenesis.',
#   'sf_start_char': 25,
#   'sf_end_char': 28,
#   'lf_start_char': 0,
#   'lf_end_char': 23,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['These include glioblastoma multiforme (GBM), which is characterized by independent but interrelated features of extensive invasion into normal brain parenchyma, rapid growth, necrosis, and angiogenesis.'],
#   'data_source': 'train',
#   'abr_whole_start': 0,
#   'abr_whole_end': 29},
#  {'abrv_text': 'GEFs',
#   'abr_definition': 'Guanine nucleotide exchange factors',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Guanine nucleotide exchange factors (GEFs) mediate RhoA activation in response to tensional forces on fibronectin-binding integrins.',
#   'sf_start_char': 37,
#   'sf_end_char': 41,
#   'lf_start_char': 0,
#   'lf_end_char': 35,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['By combining biochemical and biophysical approaches, we identified two guanine nucleotide exchange factors (GEFs), LARG and GEF-H1, as key molecules that regulate the cellular adaptation to force.'],
#   'data_source': 'train',
#   'abr_whole_start': 0,
#   'abr_whole_end': 42},
#  {'abrv_text': 'SCT',
#   'abr_definition': 'Sickle cell trait',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'HbA1c consistently overestimates glycemic control in black individuals with Sickle cell trait (SCT).',
#   'sf_start_char': 95,
#   'sf_end_char': 98,
#   'lf_start_char': 76,
#   'lf_end_char': 93,
#   'org_label': 'REFUTES',
#   'list_rationales': ['These findings suggest that HbA1c may systematically underestimate past glycemia in black patients with SCT and may require further evaluation.'],
#   'data_source': 'train',
#   'abr_whole_start': 76,
#   'abr_whole_end': 99},
#  {'abrv_text': 'COPD',
#   'abr_definition': 'chronic obstructive pulmonary disease',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'High levels of CRP lead to a higher risk of exacerbations in chronic obstructive pulmonary disease (COPD).',
#   'sf_start_char': 100,
#   'sf_end_char': 104,
#   'lf_start_char': 61,
#   'lf_end_char': 98,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['CONCLUSIONS AND RELEVANCE Simultaneously elevated levels of CRP and fibrinogen and leukocyte count in individuals with COPD were associated with increased risk of having exacerbations, even in those with milder COPD and in those without previous exacerbations.'],
#   'data_source': 'train',
#   'abr_whole_start': 61,
#   'abr_whole_end': 105},
#  {'abrv_text': 'ADEs',
#   'abr_definition': 'adverse drug events',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Including pharmacists in rounding teams does not alter the incidence of adverse drug events (ADEs).',
#   'sf_start_char': 93,
#   'sf_end_char': 97,
#   'lf_start_char': 72,
#   'lf_end_char': 91,
#   'org_label': 'REFUTES',
#   'list_rationales': ['CONCLUSIONS The presence of a pharmacist on rounds as a full member of the patient care team in a medical ICU was associated with a substantially lower rate of ADEs caused by prescribing errors.'],
#   'data_source': 'train',
#   'abr_whole_start': 72,
#   'abr_whole_end': 98},
#  {'abrv_text': 'ADEs',
#   'abr_definition': 'adverse drug events',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Including pharmacists in rounding teams reduces the incidence of adverse drug events (ADEs).',
#   'sf_start_char': 86,
#   'sf_end_char': 90,
#   'lf_start_char': 65,
#   'lf_end_char': 84,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['CONCLUSIONS The presence of a pharmacist on rounds as a full member of the patient care team in a medical ICU was associated with a substantially lower rate of ADEs caused by prescribing errors.'],
#   'data_source': 'train',
#   'abr_whole_start': 65,
#   'abr_whole_end': 91},
#  {'abrv_text': 'DBP',
#   'abr_definition': 'diastolic blood pressure',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Increased diastolic blood pressure (DBP) is associated with abdominal aortic aneurysm.',
#   'sf_start_char': 36,
#   'sf_end_char': 39,
#   'lf_start_char': 10,
#   'lf_end_char': 34,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Compared with diastolic blood pressure, raised systolic blood pressure had a greater effect on angina, myocardial infarction, and peripheral arterial disease, whereas raised diastolic blood pressure had a greater effect on abdominal aortic aneurysm than did raised systolic pressure.'],
#   'data_source': 'train',
#   'abr_whole_start': 10,
#   'abr_whole_end': 40},
#  {'abrv_text': 'FA',
#   'abr_definition': 'folic acid',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Intake of folic acid (FA) and vitamin B6 (VB6) increases levels of homocysteine.',
#   'sf_start_char': 22,
#   'sf_end_char': 24,
#   'lf_start_char': 10,
#   'lf_end_char': 20,
#   'org_label': 'REFUTES',
#   'list_rationales': ['CONTEXT Hyperhomocysteinemia is caused by genetic and lifestyle influences, including low intakes of folate and vitamin B6.'],
#   'data_source': 'train',
#   'abr_whole_start': 10,
#   'abr_whole_end': 25},
#  {'abrv_text': 'VB6',
#   'abr_definition': 'vitamin B6',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Intake of folic acid (FA) and vitamin B6 (VB6) increases levels of homocysteine.',
#   'sf_start_char': 42,
#   'sf_end_char': 45,
#   'lf_start_char': 30,
#   'lf_end_char': 40,
#   'org_label': 'REFUTES',
#   'list_rationales': ['CONTEXT Hyperhomocysteinemia is caused by genetic and lifestyle influences, including low intakes of folate and vitamin B6.'],
#   'data_source': 'train',
#   'abr_whole_start': 30,
#   'abr_whole_end': 46},
#  {'abrv_text': 'FA',
#   'abr_definition': 'folic acid',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Intake of folic acid (FA) and vitamin B6 (VB6) reduces levels of homocysteine.',
#   'sf_start_char': 22,
#   'sf_end_char': 24,
#   'lf_start_char': 10,
#   'lf_end_char': 20,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['CONTEXT Hyperhomocysteinemia is caused by genetic and lifestyle influences, including low intakes of folate and vitamin B6.'],
#   'data_source': 'train',
#   'abr_whole_start': 10,
#   'abr_whole_end': 25},
#  {'abrv_text': 'VB6',
#   'abr_definition': 'vitamin B6',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Intake of folic acid (FA) and vitamin B6 (VB6) reduces levels of homocysteine.',
#   'sf_start_char': 42,
#   'sf_end_char': 45,
#   'lf_start_char': 30,
#   'lf_end_char': 40,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['CONTEXT Hyperhomocysteinemia is caused by genetic and lifestyle influences, including low intakes of folate and vitamin B6.'],
#   'data_source': 'train',
#   'abr_whole_start': 30,
#   'abr_whole_end': 46},
#  {'abrv_text': 'MC4R',
#   'abr_definition': 'melanocortin-4 receptor',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Kir7.1 modulates channel activity by the G protein-coupled melanocortin-4 receptor (MC4R) in the paraventricular nucleus of the hypothalamus.',
#   'sf_start_char': 84,
#   'sf_end_char': 88,
#   'lf_start_char': 59,
#   'lf_end_char': 82,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Here we show that, in mice, regulation of firing activity of neurons from the paraventricular nucleus of the hypothalamus (PVN) by α-MSH and AgRP can be mediated independently of Gαs signalling by ligand-induced coupling of MC4R to closure of inwardly rectifying potassium channel, Kir7.1.'],
#   'data_source': 'train',
#   'abr_whole_start': 59,
#   'abr_whole_end': 89},
#  {'abrv_text': 'MVP',
#   'abr_definition': 'Major vault protein',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Major vault protein (MVP) leads to more aggressive tumors by regulating the sorting of tumor suppressive miR-193a into extracellular vesicles (EVs).',
#   'sf_start_char': 21,
#   'sf_end_char': 24,
#   'lf_start_char': 0,
#   'lf_end_char': 19,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['In summary, our data demonstrate that MVP-mediated selective sorting of tumour suppressor miRNA into exosomes promotes tumour progression.'],
#   'data_source': 'train',
#   'abr_whole_start': 0,
#   'abr_whole_end': 25},
#  {'abrv_text': 'EVs',
#   'abr_definition': 'extracellular vesicles',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Major vault protein (MVP) leads to more aggressive tumors by regulating the sorting of tumor suppressive miR-193a into extracellular vesicles (EVs).',
#   'sf_start_char': 143,
#   'sf_end_char': 146,
#   'lf_start_char': 119,
#   'lf_end_char': 141,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['In summary, our data demonstrate that MVP-mediated selective sorting of tumour suppressor miRNA into exosomes promotes tumour progression.'],
#   'data_source': 'train',
#   'abr_whole_start': 119,
#   'abr_whole_end': 147},
#  {'abrv_text': 'CHIKV',
#   'abr_definition': 'Chikungunya virus',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Mice are incapable of producing neutralizing antibodies in reponse to the Chikungunya virus (CHIKV) produced in mosquitos.',
#   'sf_start_char': 93,
#   'sf_end_char': 98,
#   'lf_start_char': 74,
#   'lf_end_char': 91,
#   'org_label': 'REFUTES',
#   'list_rationales': ['A single dose of EILV/CHIKV produced in mosquito cells elicited rapid (within 4 d) and long-lasting (>290 d) neutralizing antibodies that provided complete protection in two different mouse models.'],
#   'data_source': 'train',
#   'abr_whole_start': 74,
#   'abr_whole_end': 99},
#  {'abrv_text': 'NTP',
#   'abr_definition': 'nucleoside triphosphate',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Microcin J25 encourages nucleoside triphosphate (NTP) binding.',
#   'sf_start_char': 49,
#   'sf_end_char': 52,
#   'lf_start_char': 24,
#   'lf_end_char': 47,
#   'org_label': 'REFUTES',
#   'list_rationales': ['Biochemical results indicate that inhibition of transcription occurs at the level of NTP uptake or NTP binding by RNAP.'],
#   'data_source': 'train',
#   'abr_whole_start': 24,
#   'abr_whole_end': 53},
#  {'abrv_text': 'NTP',
#   'abr_definition': 'nucleoside triphosphate',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Microcin J25 inhibits nucleoside triphosphate (NTP) binding.',
#   'sf_start_char': 47,
#   'sf_end_char': 50,
#   'lf_start_char': 22,
#   'lf_end_char': 45,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Biochemical results indicate that inhibition of transcription occurs at the level of NTP uptake or NTP binding by RNAP.'],
#   'data_source': 'train',
#   'abr_whole_start': 22,
#   'abr_whole_end': 51},
#  {'abrv_text': 'NET',
#   'abr_definition': 'Neutrophil extracellular trap',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Neutrophil extracellular trap (NET) antigens may contain the targeted autoantigens PR3 and MPO.',
#   'sf_start_char': 31,
#   'sf_end_char': 34,
#   'lf_start_char': 0,
#   'lf_end_char': 29,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Here we show that chromatin fibers, so-called neutrophil extracellular traps (NETs), are released by ANCA-stimulated neutrophils and contain the targeted autoantigens proteinase-3 (PR3) and myeloperoxidase (MPO).'],
#   'data_source': 'train',
#   'abr_whole_start': 0,
#   'abr_whole_end': 35},
#  {'abrv_text': 'EILV',
#   'abr_definition': 'Eilat virus',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Nonhuman primates are incapable of producing neutralizing antibodies in reponse to the Eilat virus (EILV) produced in mosquitos.',
#   'sf_start_char': 100,
#   'sf_end_char': 104,
#   'lf_start_char': 87,
#   'lf_end_char': 98,
#   'org_label': 'REFUTES',
#   'list_rationales': ['A single dose of EILV/CHIKV produced in mosquito cells elicited rapid (within 4 d) and long-lasting (>290 d) neutralizing antibodies that provided complete protection in two different mouse models.',
#    'In nonhuman primates, EILV/CHIKV elicited rapid and robust immunity that protected against viremia and telemetrically monitored fever.'],
#   'data_source': 'train',
#   'abr_whole_start': 87,
#   'abr_whole_end': 105},
#  {'abrv_text': 'BIR',
#   'abr_definition': 'break-induced DNA replication',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'RAD52 is involved in break-induced DNA replication (BIR).',
#   'sf_start_char': 52,
#   'sf_end_char': 55,
#   'lf_start_char': 21,
#   'lf_end_char': 50,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['We therefore propose that mammalian RAD52 facilitates repair of collapsed DNA replication forks in cancer cells.'],
#   'data_source': 'train',
#   'abr_whole_start': 21,
#   'abr_whole_end': 56},
#  {'abrv_text': 'BIR',
#   'abr_definition': 'break-induced DNA replication',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'RAD52 is involved in break-induced DNA replication (BIR).',
#   'sf_start_char': 52,
#   'sf_end_char': 55,
#   'lf_start_char': 21,
#   'lf_end_char': 50,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['ALT-associated replication defects trigger mitotic DNA synthesis (MiDAS) at telomeres in a RAD52-dependent, but RAD51-independent, manner.'],
#   'data_source': 'train',
#   'abr_whole_start': 21,
#   'abr_whole_end': 56},
#  {'abrv_text': 'BIR',
#   'abr_definition': 'break-induced DNA replication',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'RAD52 is involved in break-induced DNA replication (BIR).',
#   'sf_start_char': 52,
#   'sf_end_char': 55,
#   'lf_start_char': 21,
#   'lf_end_char': 50,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['We propose a model whereby replication stress initiates a RAD52-dependent form of break-induced replication that bypasses a requirement for MUS81-EME1 to complete DNA synthesis in mitosis.'],
#   'data_source': 'train',
#   'abr_whole_start': 21,
#   'abr_whole_end': 56},
#  {'abrv_text': 'CRPC',
#   'abr_definition': 'castration-resistant prostate cancer',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Retinoic acid receptor-related orphan receptor gamma (RORγ) is a therapeutic target for castration-resistant prostate cancer (CRPC)',
#   'sf_start_char': 126,
#   'sf_end_char': 130,
#   'lf_start_char': 88,
#   'lf_end_char': 124,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Taken together, these results establish ROR-γ as a key player in CRPC by acting upstream of AR and as a potential therapeutic target for advanced PCa.'],
#   'data_source': 'train',
#   'abr_whole_start': 88,
#   'abr_whole_end': 131},
#  {'abrv_text': 'IS',
#   'abr_definition': 'immunosuppressive',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Systemic immunosuppressive (IS) therapy does not enhance the chance of cancer mortality in patients with inflammatory eye disease (IED)',
#   'sf_start_char': 28,
#   'sf_end_char': 30,
#   'lf_start_char': 9,
#   'lf_end_char': 26,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['CONCLUSIONS Most commonly used immunosuppressive drugs do not seem to increase overall or cancer mortality.'],
#   'data_source': 'train',
#   'abr_whole_start': 9,
#   'abr_whole_end': 31},
#  {'abrv_text': 'IED',
#   'abr_definition': 'inflammatory eye disease',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Systemic immunosuppressive (IS) therapy does not enhance the chance of cancer mortality in patients with inflammatory eye disease (IED)',
#   'sf_start_char': 131,
#   'sf_end_char': 134,
#   'lf_start_char': 105,
#   'lf_end_char': 129,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['CONCLUSIONS Most commonly used immunosuppressive drugs do not seem to increase overall or cancer mortality.'],
#   'data_source': 'train',
#   'abr_whole_start': 105,
#   'abr_whole_end': 135},
#  {'abrv_text': 'IS',
#   'abr_definition': 'immunosuppressive',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Systemic immunosuppressive (IS) therapy increases the chance of cancer mortality in patients with inflammatory eye disease (IED)',
#   'sf_start_char': 28,
#   'sf_end_char': 30,
#   'lf_start_char': 9,
#   'lf_end_char': 26,
#   'org_label': 'REFUTES',
#   'list_rationales': ['CONCLUSIONS Most commonly used immunosuppressive drugs do not seem to increase overall or cancer mortality.'],
#   'data_source': 'train',
#   'abr_whole_start': 9,
#   'abr_whole_end': 31},
#  {'abrv_text': 'IED',
#   'abr_definition': 'inflammatory eye disease',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Systemic immunosuppressive (IS) therapy increases the chance of cancer mortality in patients with inflammatory eye disease (IED)',
#   'sf_start_char': 124,
#   'sf_end_char': 127,
#   'lf_start_char': 98,
#   'lf_end_char': 122,
#   'org_label': 'REFUTES',
#   'list_rationales': ['CONCLUSIONS Most commonly used immunosuppressive drugs do not seem to increase overall or cancer mortality.'],
#   'data_source': 'train',
#   'abr_whole_start': 98,
#   'abr_whole_end': 128},
#  {'abrv_text': 'RIP',
#   'abr_definition': 'receptor-interacting protein',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'The NF-κB essential modulator gene induces intestinal inflammation by promoting receptor-interacting protein (RIP) kinase 1 kinase activity-mediated epithelial cell death.',
#   'sf_start_char': 110,
#   'sf_end_char': 113,
#   'lf_start_char': 80,
#   'lf_end_char': 108,
#   'org_label': 'REFUTES',
#   'list_rationales': ['Therefore, NEMO prevents intestinal inflammation by inhibiting RIPK1 kinase activity-mediated IEC death, suggesting that RIPK1 inhibitors could be effective in the treatment of colitis in patients with NEMO mutations and possibly in IBD.'],
#   'data_source': 'train',
#   'abr_whole_start': 80,
#   'abr_whole_end': 114},
#  {'abrv_text': 'RIP',
#   'abr_definition': 'receptor-interacting protein',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'The NF-κB essential modulator gene prevents intestinal inflammation by inhibiting receptor-interacting protein (RIP) kinase 1 kinase activity-mediated epithelial cell death.',
#   'sf_start_char': 112,
#   'sf_end_char': 115,
#   'lf_start_char': 82,
#   'lf_end_char': 110,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Therefore, NEMO prevents intestinal inflammation by inhibiting RIPK1 kinase activity-mediated IEC death, suggesting that RIPK1 inhibitors could be effective in the treatment of colitis in patients with NEMO mutations and possibly in IBD.'],
#   'data_source': 'train',
#   'abr_whole_start': 82,
#   'abr_whole_end': 116},
#  {'abrv_text': 'RANKL',
#   'abr_definition': 'RANK-RANK-Ligand',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'The RANK-RANK-Ligand (RANKL) pathway is involved in the development of Aire-expressing medullary thymic epithelial cells (mTECs).',
#   'sf_start_char': 22,
#   'sf_end_char': 27,
#   'lf_start_char': 4,
#   'lf_end_char': 20,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Hence, our data attributed a functional importance to the temporal development of Vγ5(+) γδ T cells during thymus medulla formation for αβ T cell tolerance induction and demonstrated a Rank-mediated reciprocal link between DETC and Aire(+) mTEC maturation.'],
#   'data_source': 'train',
#   'abr_whole_start': 4,
#   'abr_whole_end': 28},
#  {'abrv_text': 'mTECs',
#   'abr_definition': 'medullary thymic epithelial cells',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'The RANK-RANK-Ligand (RANKL) pathway is involved in the development of Aire-expressing medullary thymic epithelial cells (mTECs).',
#   'sf_start_char': 122,
#   'sf_end_char': 127,
#   'lf_start_char': 87,
#   'lf_end_char': 120,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Hence, our data attributed a functional importance to the temporal development of Vγ5(+) γδ T cells during thymus medulla formation for αβ T cell tolerance induction and demonstrated a Rank-mediated reciprocal link between DETC and Aire(+) mTEC maturation.'],
#   'data_source': 'train',
#   'abr_whole_start': 87,
#   'abr_whole_end': 128},
#  {'abrv_text': 'RANKL',
#   'abr_definition': 'RANK-RANK-Ligand',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'The RANK-RANK-Ligand (RANKL) pathway is involved in the development of Aire-expressing medullary thymic epithelial cells (mTECs).',
#   'sf_start_char': 22,
#   'sf_end_char': 27,
#   'lf_start_char': 4,
#   'lf_end_char': 20,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['These results show that developmental-stage-dependent cooperation between RANK and CD40 promotes mTEC development, thereby establishing self-tolerance.'],
#   'data_source': 'train',
#   'abr_whole_start': 4,
#   'abr_whole_end': 28},
#  {'abrv_text': 'mTECs',
#   'abr_definition': 'medullary thymic epithelial cells',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'The RANK-RANK-Ligand (RANKL) pathway is involved in the development of Aire-expressing medullary thymic epithelial cells (mTECs).',
#   'sf_start_char': 122,
#   'sf_end_char': 127,
#   'lf_start_char': 87,
#   'lf_end_char': 120,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['These results show that developmental-stage-dependent cooperation between RANK and CD40 promotes mTEC development, thereby establishing self-tolerance.'],
#   'data_source': 'train',
#   'abr_whole_start': 87,
#   'abr_whole_end': 128},
#  {'abrv_text': 'RANKL',
#   'abr_definition': 'RANK-RANK-Ligand',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'The RANK-RANK-Ligand (RANKL) pathway is involved in the development of Aire-expressing medullary thymic epithelial cells (mTECs).',
#   'sf_start_char': 22,
#   'sf_end_char': 27,
#   'lf_start_char': 4,
#   'lf_end_char': 20,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Here we show that the cytokine RANK ligand (RANKL) was produced by positively selected thymocytes and regulated the cellularity of mTEC by interacting with RANK and osteoprotegerin.'],
#   'data_source': 'train',
#   'abr_whole_start': 4,
#   'abr_whole_end': 28},
#  {'abrv_text': 'mTECs',
#   'abr_definition': 'medullary thymic epithelial cells',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'The RANK-RANK-Ligand (RANKL) pathway is involved in the development of Aire-expressing medullary thymic epithelial cells (mTECs).',
#   'sf_start_char': 122,
#   'sf_end_char': 127,
#   'lf_start_char': 87,
#   'lf_end_char': 120,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Here we show that the cytokine RANK ligand (RANKL) was produced by positively selected thymocytes and regulated the cellularity of mTEC by interacting with RANK and osteoprotegerin.'],
#   'data_source': 'train',
#   'abr_whole_start': 87,
#   'abr_whole_end': 128},
#  {'abrv_text': 'RANKL',
#   'abr_definition': 'RANK-RANK-Ligand',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'The RANK-RANK-Ligand (RANKL) pathway is involved in the development of Aire-expressing medullary thymic epithelial cells (mTECs).',
#   'sf_start_char': 22,
#   'sf_end_char': 27,
#   'lf_start_char': 4,
#   'lf_end_char': 20,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Collectively, our data reveal cellular and molecular mechanisms leading to the generation of Aire+ mTECs and highlight a previously unrecognized role for CD4+3−RANKL+ inducer cells in intrathymic self-tolerance.'],
#   'data_source': 'train',
#   'abr_whole_start': 4,
#   'abr_whole_end': 28},
#  {'abrv_text': 'mTECs',
#   'abr_definition': 'medullary thymic epithelial cells',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'The RANK-RANK-Ligand (RANKL) pathway is involved in the development of Aire-expressing medullary thymic epithelial cells (mTECs).',
#   'sf_start_char': 122,
#   'sf_end_char': 127,
#   'lf_start_char': 87,
#   'lf_end_char': 120,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Collectively, our data reveal cellular and molecular mechanisms leading to the generation of Aire+ mTECs and highlight a previously unrecognized role for CD4+3−RANKL+ inducer cells in intrathymic self-tolerance.'],
#   'data_source': 'train',
#   'abr_whole_start': 87,
#   'abr_whole_end': 128},
#  {'abrv_text': 'MMPs',
#   'abr_definition': 'matrix metalloproteases',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'The microtubule-dependent delivery and secretion of matrix metalloproteases (MMPs) is partially responsible for the disassembly of adhesion sites.',
#   'sf_start_char': 77,
#   'sf_end_char': 81,
#   'lf_start_char': 52,
#   'lf_end_char': 75,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['CLASPs are further required for FA-associated ECM degradation, and matrix metalloprotease inhibition slows FA disassembly similarly to CLASP or PHLDB2 (LL5β) depletion.'],
#   'data_source': 'train',
#   'abr_whole_start': 52,
#   'abr_whole_end': 82},
#  {'abrv_text': 'RVD',
#   'abr_definition': 'repeat-variable diresidue',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'The repeat-variable diresidue (RVD) in the loop of Transcription-Activator Like (TAL) effectors specifies the nucleotides-amino acid contact at the target promoter element.',
#   'sf_start_char': 31,
#   'sf_end_char': 34,
#   'lf_start_char': 4,
#   'lf_end_char': 29,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['TAL (transcription activator-like) effectors, secreted by phytopathogenic bacteria, recognize host DNA sequences through a central domain of tandem repeats.',
#    'Each repeat comprises 33 to 35 conserved amino acids and targets a specific base pair by using two hypervariable residues [known as repeat variable diresidues (RVDs)] at positions 12 and 13.'],
#   'data_source': 'train',
#   'abr_whole_start': 4,
#   'abr_whole_end': 35},
#  {'abrv_text': 'TAL',
#   'abr_definition': 'Transcription-Activator Like',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'The repeat-variable diresidue (RVD) in the loop of Transcription-Activator Like (TAL) effectors specifies the nucleotides-amino acid contact at the target promoter element.',
#   'sf_start_char': 81,
#   'sf_end_char': 84,
#   'lf_start_char': 51,
#   'lf_end_char': 79,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['TAL (transcription activator-like) effectors, secreted by phytopathogenic bacteria, recognize host DNA sequences through a central domain of tandem repeats.',
#    'Each repeat comprises 33 to 35 conserved amino acids and targets a specific base pair by using two hypervariable residues [known as repeat variable diresidues (RVDs)] at positions 12 and 13.'],
#   'data_source': 'train',
#   'abr_whole_start': 51,
#   'abr_whole_end': 85},
#  {'abrv_text': 'miRNA',
#   'abr_definition': 'microRNA',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'miR-142-5P is a temperature-sensitive microRNA (miRNA).',
#   'sf_start_char': 48,
#   'sf_end_char': 53,
#   'lf_start_char': 38,
#   'lf_end_char': 46,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Reduced RBM3 expression resulted in increased expression of RBM3-targeted temperature-sensitive miRNAs, we termed thermomiRs.',
#    'ThermomiRs such as miR-142-5p and miR-143 in turn target endogenous pyrogens including IL-6, IL6ST, TLR2, PGE2 and TNF to complete a negative feedback mechanism, which may be crucial to prevent pathological hyperthermia.'],
#   'data_source': 'train',
#   'abr_whole_start': 38,
#   'abr_whole_end': 54},
#  {'abrv_text': 'AMPK',
#   'abr_definition': 'AMP-activated protein kinase',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'AMP-activated protein kinase (AMPK) activation increases inflammation-related fibrosis in the lungs.',
#   'sf_start_char': 30,
#   'sf_end_char': 34,
#   'lf_start_char': 0,
#   'lf_end_char': 28,
#   'org_label': 'REFUTES',
#   'list_rationales': ['These studies implicate deficient AMPK activation in non-resolving, pathologic fibrotic processes, and support a role for metformin (or other AMPK activators) to reverse established fibrosis by facilitating deactivation and apoptosis of myofibroblasts.'],
#   'data_source': 'dev',
#   'abr_whole_start': 0,
#   'abr_whole_end': 35},
#  {'abrv_text': 'SLE',
#   'abr_definition': 'systemic lupus erythematosus',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Basophils counteract disease development in patients with systemic lupus erythematosus (SLE).',
#   'sf_start_char': 88,
#   'sf_end_char': 91,
#   'lf_start_char': 58,
#   'lf_end_char': 86,
#   'org_label': 'REFUTES',
#   'list_rationales': ['Thus, in Lyn(-/-) mice, basophils and IgE autoantibodies amplify autoantibody production that leads to lupus nephritis, and in individuals with SLE IgE autoantibodies and activated basophils are factors associated with disease activity and nephritis.'],
#   'data_source': 'dev',
#   'abr_whole_start': 58,
#   'abr_whole_end': 92},
#  {'abrv_text': 'ComYMV',
#   'abr_definition': "Commelina yellow mottle virus'",
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': "Commelina yellow mottle virus' (ComYMV) genome consists of 7489 baise pairs.",
#   'sf_start_char': 32,
#   'sf_end_char': 38,
#   'lf_start_char': 0,
#   'lf_end_char': 30,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Analysis of the genome sequence indicates that the genome is 7489 bp in size and that the transcribed strand contains three open reading frames capable of encoding proteins of 23, 15 and 216 kd.'],
#   'data_source': 'dev',
#   'abr_whole_start': 0,
#   'abr_whole_end': 39},
#  {'abrv_text': 'DCs',
#   'abr_definition': 'dendritic cells',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Crosstalk between dendritic cells (DCs) and innate lymphoid cells (ILCs) is important in the regulation of intestinal homeostasis.',
#   'sf_start_char': 35,
#   'sf_end_char': 38,
#   'lf_start_char': 18,
#   'lf_end_char': 33,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['The importance of IL-7R signaling in TRUC disease was highlighted by the dramatic reduction in intestinal ILCs and attenuated colitis following IL-7R blockade.',
#    'Taken together, these data demonstrate the mechanism by which T-bet regulates the complex interplay between mucosal dendritic cells, ILCs, and the intestinal microbiota.'],
#   'data_source': 'dev',
#   'abr_whole_start': 18,
#   'abr_whole_end': 39},
#  {'abrv_text': 'ILCs',
#   'abr_definition': 'innate lymphoid cells',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Crosstalk between dendritic cells (DCs) and innate lymphoid cells (ILCs) is important in the regulation of intestinal homeostasis.',
#   'sf_start_char': 67,
#   'sf_end_char': 71,
#   'lf_start_char': 44,
#   'lf_end_char': 65,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['The importance of IL-7R signaling in TRUC disease was highlighted by the dramatic reduction in intestinal ILCs and attenuated colitis following IL-7R blockade.',
#    'Taken together, these data demonstrate the mechanism by which T-bet regulates the complex interplay between mucosal dendritic cells, ILCs, and the intestinal microbiota.'],
#   'data_source': 'dev',
#   'abr_whole_start': 44,
#   'abr_whole_end': 72},
#  {'abrv_text': 'cells',
#   'abr_definition': 'cells (ILCs',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Crosstalk between dendritic cells (DCs) and innate lymphoid cells (ILCs) is important in the regulation of intestinal homeostasis.',
#   'sf_start_char': 28,
#   'sf_end_char': 33,
#   'lf_start_char': 60,
#   'lf_end_char': 71,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['The importance of IL-7R signaling in TRUC disease was highlighted by the dramatic reduction in intestinal ILCs and attenuated colitis following IL-7R blockade.',
#    'Taken together, these data demonstrate the mechanism by which T-bet regulates the complex interplay between mucosal dendritic cells, ILCs, and the intestinal microbiota.'],
#   'data_source': 'dev',
#   'abr_whole_start': 28,
#   'abr_whole_end': 72},
#  {'abrv_text': 'EMAs',
#   'abr_definition': 'Epigenetic modulating agents',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Epigenetic modulating agents (EMAs) modulate antitumor immune response in a cancer model system.',
#   'sf_start_char': 30,
#   'sf_end_char': 34,
#   'lf_start_char': 0,
#   'lf_end_char': 28,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Use of this combination treatment schema in mouse models of NSCLC reverses tumor immune evasion and modulates T cell exhaustion state towards memory and effector T cell phenotypes.'],
#   'data_source': 'dev',
#   'abr_whole_start': 0,
#   'abr_whole_end': 35},
#  {'abrv_text': 'APOE4',
#   'abr_definition': 'Apolipoprotein E4',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Female carriers of the Apolipoprotein E4 (APOE4) allele have increased risk for dementia.',
#   'sf_start_char': 42,
#   'sf_end_char': 47,
#   'lf_start_char': 23,
#   'lf_end_char': 40,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Risk of dementia associated with a longer reproductive period was most pronounced in APOE epsilon4 carriers (adjusted RR for >39 reproductive years compared with <34 reproductive years, 4.20 [95% CI, 1.97-8.92] for dementia and 3.42 [95% CI, 1.51-7.75] for AD), whereas in noncarriers, no clear association with dementia or AD was observed.   \n'],
#   'data_source': 'dev',
#   'abr_whole_start': 23,
#   'abr_whole_end': 48},
#  {'abrv_text': 'ROS',
#   'abr_definition': 'reactive oxygen species',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'FoxO3a activation in neuronal death is mediated by reactive oxygen species (ROS).',
#   'sf_start_char': 76,
#   'sf_end_char': 79,
#   'lf_start_char': 51,
#   'lf_end_char': 74,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Thus, one way in which members of the Sir2 family of proteins may increase organismal longevity is by tipping FOXO-dependent responses away from apoptosis and toward stress resistance.'],
#   'data_source': 'dev',
#   'abr_whole_start': 51,
#   'abr_whole_end': 80},
#  {'abrv_text': 'HSC',
#   'abr_definition': 'hematopoietic stem cell',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'GATA-3 is important for hematopoietic stem cell (HSC) function.',
#   'sf_start_char': 49,
#   'sf_end_char': 52,
#   'lf_start_char': 24,
#   'lf_end_char': 47,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['In the present study, we show that Gata3-null mutant mice generate fewer LT-HSCs and that fewer Gata3-null LT-HSCs are in cycle.',
#    'Furthermore, Gata3 mutant hematopoietic progenitor cells fail to be recruited into an increased cycling state after 5-fluorouracil-induced myelosuppression.',
#    'Therefore, GATA-3 is required for the maintenance of a normal number of LT-HSCs and for their entry into the cell cycle.'],
#   'data_source': 'dev',
#   'abr_whole_start': 24,
#   'abr_whole_end': 53},
#  {'abrv_text': 'COPD',
#   'abr_definition': 'chronic obstructive pulmonary disease',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'High levels of CRP reduces the risk of exacerbations in chronic obstructive pulmonary disease (COPD).',
#   'sf_start_char': 95,
#   'sf_end_char': 99,
#   'lf_start_char': 56,
#   'lf_end_char': 93,
#   'org_label': 'REFUTES',
#   'list_rationales': ['CONCLUSIONS AND RELEVANCE Simultaneously elevated levels of CRP and fibrinogen and leukocyte count in individuals with COPD were associated with increased risk of having exacerbations, even in those with milder COPD and in those without previous exacerbations.'],
#   'data_source': 'dev',
#   'abr_whole_start': 56,
#   'abr_whole_end': 100},
#  {'abrv_text': 'HSCT-T',
#   'abr_definition': 'High-sensitivity cardiac troponin T',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'High-sensitivity cardiac troponin T (HSCT-T) dosage may not be diagnostic if the onset of symptoms occurs less than 3 hours before acute myocardial injury (AMI).',
#   'sf_start_char': 37,
#   'sf_end_char': 43,
#   'lf_start_char': 0,
#   'lf_end_char': 35,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['However, this method should be part of a comprehensive triage strategy and may not be appropriate for patients who present less than three hours after symptom onset.'],
#   'data_source': 'dev',
#   'abr_whole_start': 0,
#   'abr_whole_end': 44},
#  {'abrv_text': 'AMI',
#   'abr_definition': 'acute myocardial injury',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'High-sensitivity cardiac troponin T (HSCT-T) dosage may not be diagnostic if the onset of symptoms occurs less than 3 hours before acute myocardial injury (AMI).',
#   'sf_start_char': 156,
#   'sf_end_char': 159,
#   'lf_start_char': 131,
#   'lf_end_char': 154,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['However, this method should be part of a comprehensive triage strategy and may not be appropriate for patients who present less than three hours after symptom onset.'],
#   'data_source': 'dev',
#   'abr_whole_start': 131,
#   'abr_whole_end': 160},
#  {'abrv_text': 'HAM/TSP',
#   'abr_definition': 'Human T-lymphotropic virus type-I-associated myelopathy / tropical spastic paraparesis',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Human T-lymphotropic virus type-I-associated myelopathy / tropical spastic paraparesis (HAM/TSP) patients produce Immunoglobulin G (IgG) antibodies which cross-react with an immunodominant epitope in Tax.',
#   'sf_start_char': 88,
#   'sf_end_char': 95,
#   'lf_start_char': 0,
#   'lf_end_char': 86,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Antibodies to hnRNP-A1 cross-reacted with HTLV-1-tax, the immune response to which is associated with HAM/TSP (refs.'],
#   'data_source': 'dev',
#   'abr_whole_start': 0,
#   'abr_whole_end': 96},
#  {'abrv_text': 'IgG',
#   'abr_definition': 'Immunoglobulin G',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Human T-lymphotropic virus type-I-associated myelopathy / tropical spastic paraparesis (HAM/TSP) patients produce Immunoglobulin G (IgG) antibodies which cross-react with an immunodominant epitope in Tax.',
#   'sf_start_char': 132,
#   'sf_end_char': 135,
#   'lf_start_char': 114,
#   'lf_end_char': 130,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Antibodies to hnRNP-A1 cross-reacted with HTLV-1-tax, the immune response to which is associated with HAM/TSP (refs.'],
#   'data_source': 'dev',
#   'abr_whole_start': 114,
#   'abr_whole_end': 136},
#  {'abrv_text': 'NSC',
#   'abr_definition': 'Neural Stem Cell',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'MicroRNA is involved in the regulation of Neural Stem Cell (NSC) differentiation and proliferation dynamic homeostasis',
#   'sf_start_char': 60,
#   'sf_end_char': 63,
#   'lf_start_char': 42,
#   'lf_end_char': 58,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['High levels of miR-184 promoted proliferation but inhibited differentiation of aNSCs, whereas inhibition of miR-184 rescued the phenotypes associated with MBD1 deficiency.'],
#   'data_source': 'dev',
#   'abr_whole_start': 42,
#   'abr_whole_end': 64},
#  {'abrv_text': 'NETs',
#   'abr_definition': 'Neutrophil extracellular traps',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Neutrophil extracellular traps (NETs) are released by ANCA-stimulated neutrophils.',
#   'sf_start_char': 32,
#   'sf_end_char': 36,
#   'lf_start_char': 0,
#   'lf_end_char': 30,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Here we show that chromatin fibers, so-called neutrophil extracellular traps (NETs), are released by ANCA-stimulated neutrophils and contain the targeted autoantigens proteinase-3 (PR3) and myeloperoxidase (MPO).'],
#   'data_source': 'dev',
#   'abr_whole_start': 0,
#   'abr_whole_end': 37},
#  {'abrv_text': 'E. coli',
#   'abr_definition': 'Escherichia coli',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'The tip of the inner tube of the toxic type VI secretion system (T6SS) antibacterial effector in Escherichia coli (E. coli) carries toxic effector proteins.',
#   'sf_start_char': 115,
#   'sf_end_char': 122,
#   'lf_start_char': 97,
#   'lf_end_char': 113,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['Our results indicate a new model of the T6SS organelle in which the VgrG-PAAR spike complex is decorated with multiple effectors that are delivered simultaneously into target cells in a single contraction-driven translocation event.'],
#   'data_source': 'dev',
#   'abr_whole_start': 97,
#   'abr_whole_end': 123},
#  {'abrv_text': 'GCS',
#   'abr_definition': 'graduated compression stockings',
#   'abr_model': 'en_ner_jnlpba_md',
#   'claim': 'Thigh-length graduated compression stockings (GCS) did not reduce deep vein thrombosis in patients admitted to hospital who are immobile because of acute stroke.',
#   'sf_start_char': 46,
#   'sf_end_char': 49,
#   'lf_start_char': 13,
#   'lf_end_char': 44,
#   'org_label': 'SUPPORTS',
#   'list_rationales': ['INTERPRETATION These data do not lend support to the use of thigh-length GCS in patients admitted to hospital with acute stroke.'],
#   'data_source': 'dev',
#   'abr_whole_start': 13,
#   'abr_whole_end': 50}]

# %%
df_sentence_word_unq_abr = pd.DataFrame(all_sentence_abbr)

# %%
df_sentence_word_unq_abr
# Out:
#    abrv_text                   abr_definition         abr_model  \
# 0        CKD           chronic kidney disease  en_ner_jnlpba_md
# 1        Th2                  T helper 2 cell  en_ner_jnlpba_md
# 2        SLE     systemic lupus erythematosus  en_ner_jnlpba_md
# 3       AMPK     AMP-activated protein kinase  en_ner_jnlpba_md
# 4       ESCs             embryonic stem cells  en_ner_jnlpba_md
# ..       ...                              ...               ...
# 79       IgG                 Immunoglobulin G  en_ner_jnlpba_md
# 80       NSC                 Neural Stem Cell  en_ner_jnlpba_md
# 81      NETs   Neutrophil extracellular traps  en_ner_jnlpba_md
# 82   E. coli                 Escherichia coli  en_ner_jnlpba_md
# 83       GCS  graduated compression stockings  en_ner_jnlpba_md
#
#                                                 claim  sf_start_char  \
# 0   40mg/day dosage of folic acid and 2mg/day dosa...            104
# 1   A T helper 2 cell (Th2) environment impedes di...             19
# 2   A T helper 2 cell (Th2) environment impedes di...            111
# 3   AMP-activated protein kinase (AMPK) activation...             30
# 4   Androgenetic haploid mouse embryonic stem cell...             49
# ..                                                ...            ...
# 79  Human T-lymphotropic virus type-I-associated m...            132
# 80  MicroRNA is involved in the regulation of Neur...             60
# 81  Neutrophil extracellular traps (NETs) are rele...             32
# 82  The tip of the inner tube of the toxic type VI...            115
# 83  Thigh-length graduated compression stockings (...             46
#
#     sf_end_char  lf_start_char  lf_end_char org_label  \
# 0           107             80          102  SUPPORTS
# 1            22              2           17   REFUTES
# 2           114             81          109   REFUTES
# 3            34              0           28  SUPPORTS
# 4            53             27           47  SUPPORTS
# ..          ...            ...          ...       ...
# 79          135            114          130  SUPPORTS
# 80           63             42           58  SUPPORTS
# 81           36              0           30  SUPPORTS
# 82          122             97          113  SUPPORTS
# 83           49             13           44  SUPPORTS
#
#                                       list_rationales data_source  \
# 0   [CONCLUSION Treatment with high doses of folic...       train
# 1   [Thus, in Lyn(-/-) mice, basophils and IgE aut...       train
# 2   [Thus, in Lyn(-/-) mice, basophils and IgE aut...       train
# 3   [These studies implicate deficient AMPK activa...       train
# 4   [Our results demonstrate that AG-haESCs can be...       train
# ..                                                ...         ...
# 79  [Antibodies to hnRNP-A1 cross-reacted with HTL...         dev
# 80  [High levels of miR-184 promoted proliferation...         dev
# 81  [Here we show that chromatin fibers, so-called...         dev
# 82  [Our results indicate a new model of the T6SS ...         dev
# 83  [INTERPRETATION These data do not lend support...         dev
#
#     abr_whole_start  abr_whole_end
# 0                80            108
# 1                 2             23
# 2                81            115
# 3                 0             35
# 4                27             54
# ..              ...            ...
# 79              114            136
# 80               42             64
# 81                0             37
# 82               97            123
# 83               13             50
#
# [84 rows x 13 columns]

# %%
df_sentence_word_unq_abr['abr_model'].value_counts()
# Out:
# en_ner_jnlpba_md    84
# Name: abr_model, dtype: int64

# %% [markdown]
# ## NER

# %%
from pattern.en import quantify, numerals, number,reflect

from nltk.corpus import wordnet as wn_nltk
from itertools import chain

from pattern.en import NOUN, VERB, ADJECTIVE, ADVERB, NOUN, VERB, ADJ, ADV, PRON, DET, PREP, ADP, NUM, CONJ, INTJ, PRT, PUNC, X
from pattern.en import  POS, CHUNK, INFINITIVE, PRESENT, PAST, FUTURE, FIRST, SECOND, THIRD,SINGULAR, PLURAL, SG, PL, PROGRESSIVE, PARTICIPLE, WORD
from pattern.text import UNIVERSAL
from pattern.en import conjugate, lemma, lexeme,PRESENT,SG, verbs, PARTICIPLE, ngrams
from pattern.en import wordnet as wn_pattern

from pattern.en import tree
from pattern.text.tree import Word
from pattern.en import parse, parsetree, tag, pprint

# %% [raw]
# import spacy
#
# # nlp = spacy.load("en_core_web_trf")
#
# from spacy import displacy
# from nltk import word_tokenize
# import nltk

# %% [raw]
# nlp_sci_brt = spacy.load("en_core_sci_scibert")
# nlp_sci_lg = spacy.load("en_core_sci_lg")
#
# #import en_ner_bc5cdr_md
# nlp_cr = spacy.load("en_ner_craft_md")
# nlp_bc = spacy.load("en_ner_bc5cdr_md")
# nlp_bi = spacy.load("en_ner_bionlp13cg_md")
# nlp_jn = spacy.load("en_ner_jnlpba_md")
#
# nlp_core_web_trf = spacy.load("en_core_web_trf")

# %%
df_claim_evid_label.shape
# Out:
# (773, 4)

# %%
all_sentence_word_ner = []
for cur_index, cur_row in tqdm(df_claim_evid_label.iterrows(), total = len(df_claim_evid_label)):
#     doc_sci_brt = nlp_sci_brt(txt)
#     doc_sci_lg = nlp_sci_lg(txt)

    cur_claim = cur_row['claim']
    doc_cr = nlp_cr(cur_claim)
    doc_bc = nlp_bc(cur_claim)
    doc_bi = nlp_bi(cur_claim)
    doc_jn = nlp_jn(cur_claim)
    
    

    
#         all_tags.append({'ner_text': cur_ent.text, 'ner_label' : cur_ent.label_, 'ner_model' : 'en_core_sci_scibert', 'claim' : txt})
    
#     for cur_ent in doc_sci_lg.ents:
#         all_tags.append({'ner_text': cur_ent.text, 'ner_label' : cur_ent.label_, 'ner_model' : 'en_core_sci_lg', 'claim' : txt})

    
    cur_all_tags = {}
    
#     for cur_ent in doc_sci_brt.ents:
#         cur_all_tags[cur_ent.text] = {'ner_text': cur_ent.text, 'ner_label' : cur_ent.label_, 'ner_model' : 'en_core_sci_scibert', 'claim' : txt, 'start_char' : cur_ent.start_char, 'end_char' : cur_ent.end_char}

    for cur_ent in doc_cr.ents:      
        
        cur_all_tags[cur_ent.text] = {'ner_text': cur_ent.text, 'ner_label' : cur_ent.label_, 
                                      'ner_model' : 'en_ner_craft_md', 'claim' : cur_claim, 'start_char' : cur_ent.start_char, 
                                      'end_char' : cur_ent.end_char, 'org_label' : cur_row['label'], 'list_rationales' : cur_row['list_rationales'],
                                      'data_source' : cur_row['source']}
    
    for cur_ent in doc_bc.ents:
        cur_all_tags[cur_ent.text] = {'ner_text': cur_ent.text, 'ner_label' : cur_ent.label_, 
                                      'ner_model' : 'en_ner_bc5cdr_md', 'claim' : cur_claim, 'start_char' : cur_ent.start_char, 
                                      'end_char' : cur_ent.end_char, 'org_label' : cur_row['label'], 'list_rationales' : cur_row['list_rationales'],
                                      'data_source' : cur_row['source']}
        
    for cur_ent in doc_bi.ents:
        cur_all_tags[cur_ent.text] = {'ner_text': cur_ent.text, 'ner_label' : cur_ent.label_, 
                                      'ner_model' : 'en_ner_bionlp13cg_md', 'claim' : cur_claim, 'start_char' : cur_ent.start_char, 
                                      'end_char' : cur_ent.end_char, 'org_label' : cur_row['label'], 'list_rationales' : cur_row['list_rationales'],
                                      'data_source' : cur_row['source']}
    
    for cur_ent in doc_jn.ents:
        cur_all_tags[cur_ent.text] = {'ner_text': cur_ent.text, 'ner_label' : cur_ent.label_, 
                                      'ner_model' : 'en_ner_jnlpba_md', 'claim' : cur_claim, 'start_char' : cur_ent.start_char, 
                                      'end_char' : cur_ent.end_char, 'org_label' : cur_row['label'], 'list_rationales' : cur_row['list_rationales'],
                                      'data_source' : cur_row['source']}
    
    
    all_sentence_word_ner.extend(list(cur_all_tags.values()))
# Out:
# 100%|██████████| 773/773 [00:22<00:00, 33.82it/s]

# %%
df_sentence_word_unq_ner = pd.DataFrame(all_sentence_word_ner)

# %%
df_sentence_word_unq_abr_ext = df_sentence_word_unq_abr.copy()

# %%
df_sentence_word_unq_abr_ext['comment'] = 'abbreviation'
df_sentence_word_unq_abr_ext['whole_text'] = df_sentence_word_unq_abr_ext['abr_definition'] + " ("+ df_sentence_word_unq_abr_ext['abrv_text'] + ")"

df_sentence_word_unq_abr_ext.rename(columns = {'whole_text' : 'ner_text', 'comment' : 'ner_label', 'abr_model' :'ner_model', 
                                                'claim' : 'claim', 'abr_whole_start' : 'start_char', 'abr_whole_end' : 'end_char'}, inplace= True)

# %%
df_sentence_word_unq_ner_abr = df_sentence_word_unq_ner.append(df_sentence_word_unq_abr_ext[['ner_label', 'ner_text', 'ner_model', 
                                                'claim', 'start_char', 'end_char', 'org_label', 'list_rationales', 'data_source']], ignore_index= True)

df_sentence_word_unq_ner_abr.sort_values(by = ['claim', 'start_char', 'end_char'], inplace= True)

df_sentence_word_unq_ner_abr.reset_index(drop= True, inplace=True)

# %%
HTML(df_sentence_word_unq_ner_abr.loc[9:19, :].sort_values(by = ['claim']).to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ner_text</th>
#       <th>ner_label</th>
#       <th>ner_model</th>
#       <th>claim</th>
#       <th>start_char</th>
#       <th>end_char</th>
#       <th>org_label</th>
#       <th>list_rationales</th>
#       <th>data_source</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>9</th>
#       <td>methadone</td>
#       <td>SIMPLE_CHEMICAL</td>
#       <td>en_ner_bionlp13cg_md</td>
#       <td>32% of liver transplantation programs required patients to discontinue methadone treatment in 2001.</td>
#       <td>71</td>
#       <td>80</td>
#       <td>SUPPORTS</td>
#       <td>[Policies requiring discontinuation of methadone in 32% of all programs contradict the evidence base for efficacy of long-term replacement therapies and potentially result in relapse of previously stable patients.]</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>40mg/day</td>
#       <td>SIMPLE_CHEMICAL</td>
#       <td>en_ner_bionlp13cg_md</td>
#       <td>40mg/day dosage of folic acid and 2mg/day dosage of vitamin B12 does not affect chronic kidney disease (CKD) progression.</td>
#       <td>0</td>
#       <td>8</td>
#       <td>SUPPORTS</td>
#       <td>[CONCLUSION Treatment with high doses of folic acid and B vitamins did not improve survival or reduce the incidence of vascular disease in patients with advanced chronic kidney disease or end-stage renal disease.   \n]</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>folic acid</td>
#       <td>SIMPLE_CHEMICAL</td>
#       <td>en_ner_bionlp13cg_md</td>
#       <td>40mg/day dosage of folic acid and 2mg/day dosage of vitamin B12 does not affect chronic kidney disease (CKD) progression.</td>
#       <td>19</td>
#       <td>29</td>
#       <td>SUPPORTS</td>
#       <td>[CONCLUSION Treatment with high doses of folic acid and B vitamins did not improve survival or reduce the incidence of vascular disease in patients with advanced chronic kidney disease or end-stage renal disease.   \n]</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>
td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>people</td>
#       <td>ORGANISM</td>
#       <td>en_ner_bionlp13cg_md</td>
#       <td>76-85% of people with severe mental disorder receive no treatment in low and middle income countries.</td>
#       <td>10</td>
#       <td>16</td>
#       <td>SUPPORTS</td>
#       <td>[Although disorder severity was correlated with probability of treatment in almost all countries, 35.5% to 50.3% of serious cases in developed countries and 76.3% to 85.4% in less-developed countries received no treatment in the 12 months before the interview.]</td>
#       <td>train</td>
#     </tr>
#   </tbody>
# </table>

# %%
def get_overlaped_span(start_1, end_1, start_2, end_2):
    if( max(end_1, end_2) - min(start_1, start_2) <= (end_1 - start_1) + (end_2 - start_2)):
        return (min(start_1, start_2) , max(end_1, end_2))
    else :
        return None

# %%
df_grp_sentence_word_unq_ner = df_sentence_word_unq_ner_abr.loc[:, :].groupby('claim')

# %%
df_sentence_word_unq_ner_abr_filtered = pd.DataFrame(columns=['ner_text', 'ner_label', 'ner_model', 
                                                'claim', 'start_char', 'end_char'])

for cur_claim, cur_df_group in tqdm(df_grp_sentence_word_unq_ner):
    cur_df_group.sort_values(by = ['start_char', 'end_char'], inplace= True)
    counter_index_outer = 0
    while counter_index_outer < len(cur_df_group):
        cur_span_start = cur_df_group['start_char']
        counter_index_inner = counter_index_outer+1
        while counter_index_inner < len(cur_df_group):  
            overlapped_span = get_overlaped_span(cur_df_group['start_char'].iloc[counter_index_outer], cur_df_group['end_char'].iloc[counter_index_outer],
                                 cur_df_group['start_char'].iloc[counter_index_inner], cur_df_group['end_char'].iloc[counter_index_inner])
            if overlapped_span != None:
                cur_df_group.loc[cur_df_group.index[counter_index_outer], 'start_char'] = overlapped_span[0]
                cur_df_group.loc[cur_df_group.index[counter_index_outer], 'end_char'] = overlapped_span[1]
                cur_df_group.drop(cur_df_group.index[[counter_index_inner]], inplace = True)
            else:
                counter_index_inner += 1 
        counter_index_outer += 1
    df_sentence_word_unq_ner_abr_filtered = df_sentence_word_unq_ner_abr_filtered.append(cur_df_group, ignore_index= True)
# Out:
#   0%|          | 0/668 [00:00<?, ?it/s]/home/qudratealahyratu/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /home/qudratealahyratu/anaconda3/envs/scifact/lib/python3.7/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# /home/qudratealahyratu/anaconda3/envs/scifact/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# 100%|██████████| 668/668 [00:03<00:00, 197.31it/s]

# %%
df_grp_sentence_word_unq_ner_abr_filtered = df_sentence_word_unq_ner_abr_filtered.loc[:, :].groupby('claim')

# %%
df_sentence_word_unq_ner_abr_filtered.to_pickle(loc_df_scispacy_sentence_word_unq_ner_abr_filtered)

# %%
dic_map_strpos_patternpos = {'NOUN' :NOUN, 'VERB' : VERB, 'ADJECTIVE': ADJECTIVE, 'ADVERB' : ADVERB}

# %%
css_style = """
        <style>
        .org_claim_container {
          background-color: #f0f6fc;
          color: #000000cc;
          border: 2px ridge #72aee655;
          border-radius: 10px;
          margin: 5px;
          padding: 10px;
        }

        .term_container{
          background-color: #faebf6;
          color: #af0000dc;
          border-radius: 5px;
          border: 2px ridge #faebf613;
          font-size: 12pt;
          font-weight: bold;
        }

        .non_term_container{
          background-color: #fff7fd;
          color: #001630;
          font-size: 12pt;
        }   
        
        .meta_info_token{
        display: block;
        background-color: #00a6f309;
        border: 1px ridge #00a6f333;
        margine : 5px;
        padding : 5px;
        font-weight: 400;
        text-shadow: 0.2px 0.2px #00000055;
        box-shadow: 1px 1px #00660022;
        }
        </style>
    """

gen_html = css_style

list_dic_of_sent_tag_info = []

for cur_claim, cur_df_group in tqdm(df_grp_sentence_word_unq_ner_abr_filtered):
    doc_sci_brt = nlp_sci_brt(cur_claim)
    list_term_ranges = cur_df_group[['start_char', 'end_char']].values
    gen_html += '<div class="org_claim_container">'
    
    
    
    previous_term_end = 0
    for cur_indx, cur_term_range in enumerate(list_term_ranges):
        
        gen_html += '<span class = "non_term_container">'+ cur_claim[previous_term_end:cur_term_range[0]]+'</span>'
        gen_html += '<span class = "term_container">'+ cur_claim[cur_term_range[0]:cur_term_range[1]]+'</span>'
        
        doc_sci_brt = nlp_sci_brt(cur_claim[previous_term_end:cur_term_range[0]])
        
        
        for cur_token in doc_sci_brt:
            dic_token_all_info = {}
#             gen_html += '<span class = "meta_info_token">'+ str({'<b>token_text': cur_token.text, '</b>token_lemma' : cur_token.lemma_, 
#                                                                  'pos' : cur_token.pos_,'dep' : cur_token.dep_, 
#                                                                  'tag' : cur_token.tag_,
#                                                                  'tag_explain' : spacy.explain(cur_token.tag_),
#                                                                 })+'</span>'
            
            
            dic_token_all_info['claim'] = cur_claim, 
            dic_token_all_info['token'] = cur_token.text 
            
#             print('org label ', set(cur_df_group['org_label']))
            dic_token_all_info['org_label'] = list(set(cur_df_group['org_label']))[0]
            dic_token_all_info['list_rationales'] = list(cur_df_group['list_rationales'])[0]
            dic_token_all_info['data_source'] = list(set(cur_df_group['data_source']))[0]
#             dic_token_all_info['claim'] = 
            
#             print('\n\n#### spacy ####')
            
#             print({'token_text': cur_token.text, 'token_lemma' : cur_token.lemma_, 
#                                                                  'pos' : cur_token.pos_,'dep' : cur_token.dep_, 
#                                                                  'tag' : cur_token.tag_,
#                                                                  'tag_explain' : spacy.explain(cur_token.tag_),                                                                 
#                                                                 })
            
            
            dic_token_all_info['token_text_spacy'] = cur_token.text 
            dic_token_all_info['token_lemma_spacy'] = cur_token.lemma_ 
            dic_token_all_info['pos_spacy'] = cur_token.pos_
            dic_token_all_info['dep_spacy'] = cur_token.dep_
            dic_token_all_info['tag_spacy'] = cur_token.tag_
            dic_token_all_info['tag_explain_spacy'] = spacy.explain(cur_token.tag_),                                                                 
                                                                
#             print('\n#### NLTK ####')
            syns_wn_nltk = wn_nltk.synsets(cur_token.text)
            synset_wn_nltk = list(set(chain.from_iterable([word.lemma_names() for word in syns_wn_nltk])))
#             print('nltk syn : ', cur_token.text, ' >>> ', synset_wn_nltk)
            dic_token_all_info['wn_nltk_syn'] = synset_wn_nltk
            
            
#             print('morph :', cur_token.morph.to_dict())
            dic_token_all_info['morf_nltk'] = cur_token.morph.to_dict()
            
#             print('\n#### Pattern ####')
            pattern_syns_list = []
            
            try:
                pattern_syns_list.append(numerals(cur_token.text))
            except :
                print()
#             word_pattern = Word(cur_claim, cur_token.text)
#             print('word_pattern > ', word_pattern.string)


#             print('lemma', ' > ', lemma(cur_token.text))
            
            
            if(cur_token.pos_ in ['NOUN', 'VERB', 'ADJECTIVE', 'ADVERB'] ):
                cur_pos = str(cur_token.pos_).upper()
#                 print("cur_token > ", cur_token.text)
                
                for synset in wn_pattern.synsets(cur_token.text, pos=dic_map_strpos_patternpos[cur_token.pos_]):
#                     print("Token pos : ", synset.pos)
#                     print("Token similar : ", synset.similar())
#                     print("synonyms : %s" % synset.synonyms)      
#                     print("pos  : %s" % synset.lexname )    
                    pattern_syns_list += synset.synonyms
            pattern_syns_list = list(set(pattern_syns_list))
            dic_token_all_info['wn_pattern_syn'] = pattern_syns_list
#             print('pattern synonyms :', pattern_syns_list)
            
            list_dic_of_sent_tag_info.append(dic_token_all_info)
        previous_term_end = cur_term_range[1]
        
    gen_html += '<span class = "non_term_container">'+cur_claim[previous_term_end:]+'</span>'
    gen_html += '</div>'
# Out:
#   0%|          | 1/668 [00:00<02:36,  4.27it/s]
#   0%|          | 2/668 [00:00<02:36,  4.25it/s]
#   0%|          | 3/668 [00:01<05:00,  2.21it/s]
#   1%|          | 4/668 [00:01<04:19,  2.55it/s]
#   1%|          | 5/668 [00:02<04:12,  2.62it/s]
#   1%|          | 6/668 [00:02<03:32,  3.12it/s]
#   1%|          | 7/668 [00:02<03:09,  3.49it/s]
#   1%|▏         | 9/668 [00:02<02:31,  4.35it/s]
#   1%|▏         | 10/668 [00:03<02:31,  4.35it/s]
#   2%|▏         | 11/668 [00:03<02:23,  4.59it/s]
#   2%|▏         | 12/668 [00:03<02:16,  4.81it/s]
#   2%|▏         | 14/668 [00:03<02:17,  4.76it/s]
#   2%|▏         | 15/668 [00:04<02:17,  4.73it/s]
#   2%|▏         | 16/668 [00:04<02:27,  4.43it/s]
#   3%|▎         | 17/668 [00:04<02:19,  4.67it/s]
#   3%|▎         | 18/668 [00:04<02:23,  4.52it/s]
#   3%|▎         | 20/668 [00:05<02:05,  5.17it/s]
#   3%|▎         | 22/668 [00:05<01:53,  5.71it/s]
#   4%|▎         | 24/668 [00:05<01:47,  6.02it/s]
#   4%|▎         | 25/668 [00:05<01:49,  5.85it/s]
#   4%|▍         | 26/668 [00:06<02:12,  4.85it/s]
#   4%|▍         | 27/668 [00:06<02:26,  4.38it/s]
#   4%|▍         | 28/668 [00:06<02:16,  4.69it/s]
#   4%|▍         | 30/668 [00:06<01:51,  5.74it/s]
#   5%|▍         | 31/668 [00:07<02:00,  5.28it/s]
#   5%|▍         | 32/668 [00:07<02:03,  5.15it/s]
#   5%|▍         | 33/668 [00:07<01:58,  5.38it/s]
#   5%|▌         | 34/668 [00:07<02:00,  5.28it/s]
#   5%|▌         | 35/668 [00:07<02:08,  4.91it/s]
#   6%|▌         | 37/668 [00:08<02:05,  5.02it/s]
#   6%|▌         | 39/668 [00:08<01:42,  6.16it/s]
#  97%|█████████▋| 649/668 [02:00<00:03,  5.45it/s]
#  97%|█████████▋| 651/668 [02:01<00:02,  6.35it/s]
#  98%|█████████▊| 652/668 [02:01<00:02,  6.99it/s]
#  98%|█████████▊| 654/668 [02:01<00:02,  6.51it/s]
#  98%|█████████▊| 655/668 [02:01<00:01,  7.19it/s]
#  98%|█████████▊| 657/668 [02:02<00:01,  6.02it/s]
#  99%|█████████▉| 660/668 [02:02<00:01,  7.49it/s]
#  99%|█████████▉| 662/668 [02:02<00:00,  7.08it/s]
#  99%|█████████▉| 664/668 [02:03<00:00,  7.59it/s]
# 100%|█████████▉| 666/668 [02:03<00:00,  6.85it/s]
# 100%|█████████▉| 667/668 [02:03<00:00,  5.62it/s]
# 100%|██████████| 668/668 [02:03<00:00,  5.40it/s]

# %%
HTML(gen_html)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aa859ffeebe8> in <module>
# ----> 1 HTML(gen_html)
#
# NameError: name 'HTML' is not defined

# %% [markdown]
# ## POS

# %%
df_non_term_toekn_info.iloc[:10,:]
# Out:
#                                                claim     token org_label  \
# 0  (1 in 5 million in UK have abnormal PrP positi...         1   REFUTES
# 1  (1 in 5 million in UK have abnormal PrP positi...        in   REFUTES
# 2  (1 in 5 million in UK have abnormal PrP positi...         5   REFUTES
# 3  (1 in 5 million in UK have abnormal PrP positi...   million   REFUTES
# 4  (1 in 5 million in UK have abnormal PrP positi...        in   REFUTES
# 5  (1 in 5 million in UK have abnormal PrP positi...             REFUTES
# 6  (1 in 5 million in UK have abnormal PrP positi...      have   REFUTES
# 7  (1 in 5 million in UK have abnormal PrP positi...  abnormal   REFUTES
# 8  (1,000 genomes project enables mapping of gene...     1,000  SUPPORTS
# 9  (1,000 genomes project enables mapping of gene...            SUPPORTS
#
#                                      list_rationales data_source  \
# 0  [RESULTS Of the 32,441 appendix samples 16 wer...       train
# 1  [RESULTS Of the 32,441 appendix samples 16 wer...       train
# 2  [RESULTS Of the 32,441 appendix samples 16 wer...       train
# 3  [RESULTS Of the 32,441 appendix samples 16 wer...       train
# 4  [RESULTS Of the 32,441 appendix samples 16 wer...       train
# 5  [RESULTS Of the 32,441 appendix samples 16 wer...       train
# 6  [RESULTS Of the 32,441 appendix samples 16 wer...       train
# 7  [RESULTS Of the 32,441 appendix samples 16 wer...       train
# 8  [In conclusion, uncommon or rare genetic varia...         dev
# 9  [In conclusion, uncommon or rare genetic varia...         dev
#
#   token_text_spacy token_lemma_spacy pos_spacy   dep_spacy tag_spacy  \
# 0                1                 1       NUM    compound        CD
# 1               in                in       ADP    quantmod        IN
# 2                5                 5       NUM    compound        CD
# 3          million           million       NUM  nmod:npmod        CD
# 4               in                in       ADP        ROOT        IN
# 5                                        SPACE         dep       _SP
# 6             have              have      VERB        ROOT        VB
# 7         abnormal          abnormal       ADJ       xcomp        JJ
# 8            1,000             1,000       NUM        ROOT        CD
# 9                                        SPACE         dep       _SP
#
#                               tag_explain_spacy  \
# 0                            (cardinal number,)
# 1  (conjunction, subordinating or preposition,)
# 2                            (cardinal number,)
# 3                            (cardinal number,)
# 4  (conjunction, subordinating or preposition,)
# 5                                       (None,)
# 6                            (verb, base form,)
# 7                                  (adjective,)
# 8                            (cardinal number,)
# 9                                       (None,)
#
#                                          wn_nltk_syn              morf_nltk  \
# 0            [single, ane, i, I, one, unity, ace, 1]    {'NumType': 'Card'}
# 1  [atomic_number_49, In, inwards, inward, inch, ...                     {}
# 2  [V, five, 5, quintet, fivesome, pentad, quint,...    {'NumType': 'Card'}
# 3  [one_thousand_thousand, trillion, zillion, bil...    {'NumType': 'Card'}
# 4  [atomic_number_49, In, inwards, inward, inch, ...                     {}
# 5                                                 []  {'PunctType': 'Peri'}
# 6  [own, stimulate, get, give, sustain, wealthy_p...    {'VerbForm': 'Inf'}
# 7                              [abnormal, unnatural]      {'Degree': 'Pos'}
# 8                                                 []    {'NumType': 'Card'}
# 9                                                 []  {'PunctType': 'Peri'}
#
#                                       wn_pattern_syn
# 0                                              [one]
# 1                                                 []
# 2                                             [five]
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6  [own, stimulate, get, give, sustain, experienc...
# 7                                                 []
# 8                                                 []
# 9                                                 []

# %%
HTML(df_non_term_toekn_info[['claim', 'token', 'token_text_spacy', 'pos_spacy', 'tag_spacy', 'tag_explain_spacy']].to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>claim</th>
#       <th>token</th>
#       <th>token_text_spacy</th>
#       <th>pos_spacy</th>
#       <th>tag_spacy</th>
#       <th>tag_explain_spacy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>(1 in 5 million in UK have abnormal PrP positivity.,)</td>
#       <td>1</td>
#       <td>1</td>
#       <td>NUM</td>
#       <td>CD</td>
#       <td>(cardinal number,)</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>(1 in 5 million in UK have abnormal PrP positivity.,)</td>
#       <td>in</td>
#       <td>in</td>
#       <td>ADP</td>
#       <td>IN</td>
#       <td>(conjunction, subordinating or preposition,)</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>(1 in 5 million in UK have abnormal PrP positivity.,)</td>
#       <td>5</td>
#       <td>5</td>
#       <td>NUM</td>
#       <td>CD</td>
#       <td>(cardinal number,)</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>(1 in 5 million in UK have abnormal PrP positivity.,)</td>
#       <td>million</td>
#       <td>million</td>
#       <td>NUM</td>
#       <td>CD</td>
#       <td>(cardinal number,)</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>(1 in 5 million in UK have abnormal PrP positivity.,)</td>
#       <td>in</td>
#       <td>in</td>
#       <td>ADP</td>
#       <td>IN</td>
#       <td>(conjunction, subordinating or preposition,)</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>(1 in 5 million in UK have abnormal PrP positivity.,)</td>
#       <td></td>
#       <td></td>
#       <td>SPACE</td>
#       <td>_SP</td>
#       <td>(None,)</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>(1 in 5 million in UK have abnormal PrP positivity.,)</td>
#       <td>have</td>
#       <td>have</td>
#       <td>VERB</td>
#       <td>VB</td>
#       <td>(verb, base form,)</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>(1 in 5 million in UK have abnormal PrP positivity.,)</td>
#       <td>abnormal</td>
#       <td>abnormal</td>
#       <td>ADJ</td>
#       <td>JJ</td>
#       <td>(adjective,)</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>(1,000 genomes project enables mapping of genetic sequence variation consisting of rare variants with larger penetrance effects than common variants.,)</td>
#       <td>1,000</td>
#       <td>1,000</td>
#       <td>NUM</td>
#       <td>CD</td>
#       <td>(cardinal number,)</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>(1,000 genomes project enables mapping of genetic sequence variation consisting of rare variants with larger penetrance effects than common variants.,)</td>
#       <td></td>
#       <td></td>
#       <td>SPACE</td>
#       <td>_SP</td>
#       <td>(None,)</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>(1,000 genomes project enables mapping of genetic sequence variation consisting of rare variants with larger penetrance effects than common variants.,)</td>
#       <td>project</td>
#       <td>project</td>
#       <td>NOUN</td>
#       <td>NN</td>
#       <td>(noun, singular or mass,)</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>(1,000 genomes project enables mapping of genetic sequence variation consisting of rare variants with larger penetrance effects than common variants.,)</td>
#       <td>enables</td>
#       <td>enables</td>
#       <td>VERB</td>
#       <td>VBZ</td>
#       <td>(verb, 3rd person singular present,)</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>(1,000 genomes project enables mapping of genetic sequence variation consisting of rare variants with larger penetrance effects than common variants.,)</td>
#       <td>mapping</td>
#       <td>mapping</td>
#       <td>NOUN</td>
#       <td>NN</td>
#       <td>(noun, singular or mass,)</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>(1,000 genomes project enables mapping of genetic sequence variation consisting of rare variants with larger penetrance effects than common variants.,)</td>
#       <td>of</td>
#       <td>of</td>
#       <td>ADP</td>
#       <td>IN</td>
#       <td>(conjunction, subordinating or preposition,)</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>(1,000 genomes project enables mapping of genetic sequence variation consisting of rare variants with larger penetrance effects than common variants.,)</td>
#       <td></td>
#       <td></td>
#       <td>SPACE</td>
#       <td>_SP</td>
#       <td>(None,)</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>(1,000 genomes project enables mapping of genetic sequence variation consisting of rare variants with larger penetrance effects than common variants.,)</td>
#       <td>variation</td>
#       <td>variation</td>
#       <td>NOUN</td>
#       <td>NN</td>
#       <td>(noun, singular or mass,)</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>(1,000 genomes project enables mapping of genetic sequence variation consisting of rare variants with larger penetrance effects than common variants.,)</td>
#       <td>consisting</td>
#       <td>consisting</td>
#       <td>VERB</td>
#       <td>VBG</td>
#       <td>(verb, gerund or present participle,)</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>(1,000 genomes project enables mapping of genetic sequence variation consisting of rare variants with larger penetrance effects than common variants.,)</td>
#       <td>of</td>
#       <td>of</td>
#       <td>ADP</td>
#       <td>IN</td>
#       <td>(conjunction, subordinating or preposition,)</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>(1,000 genomes project enables mapping of genetic sequence variation consisting of rare variants with larger penetrance effects than common variants.,)</td>
#       <td>rare</td>
#       <td>rare</td>
#       <td>ADJ</td>
#       <td>JJ</td>
#       <td>(adjective,)</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>(1,000 genomes project enables mapping of genetic sequence variation consisting of rare variants with larger penetrance effects than common variants.,)</td>
#       <td>variants</td>
#       <td>variants</td>
#       <td>NOUN</td>
#       <td>NNS</td>
#       <td>(noun, plural,)</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>(1,000 genomes project enables mapping of genetic sequence variation consisting of rare variants with larger penetrance effects than common variants.,)</td>
#       <td>with</td>
#       <td>with</td>
#       <td>ADP</td>
#       <td>IN</td>
#       <td>(conjunction, subordinating or preposition,)</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>(1,000 genomes project enables mapping of genetic sequence variation consisting of rare variants with larger penetrance effects than common variants.,)</td>
#       <td>larger</td>
#       <td>larger</td>
#       <td>ADJ</td>
#       <td>JJR</td>
#       <td>(adjective, comparative,)</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>(1,000 genomes project enables mapping of genetic sequence variation consisting of rare variants with larger penetrance effects than common variants.,)</td>
#       <td>penetrance</td>
#       <td>penetrance</td>
#       <td>NOUN</td>
#       <td>NN</td>
#       <td>(noun, singular or mass,)</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>(1,000 genomes project enables mapping of genetic sequence variation consisting of rare variants with larger penetrance effects than common variants.,)</td>
#       <td>effects</td>
#       <td>effects</td>
#       <td>NOUN</td>
#       <td>NNS</td>
#       <td>(noun, plural,)</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>(1,000 genomes project enables mapping of genetic sequence variation consisting of rare variants with larger penetrance effects than common variants.,)</td>
#       <td>than</td>
#       <td>than</td>
#       <td>SCONJ</td>
#       <td>IN</td>
#       <td>(conjunction, subordinating or preposition,)</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>(1,000 genomes project enables mapping of genetic sequence variation consisting of rare variants with larger penetrance effects than common variants.,)</td>
#       <td>common</td>
#       <td>common</td>
#       <td>ADJ</td>
#       <td>JJ</td>
#       <td>(adjective,)</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>(1/2000 in UK have abnormal PrP positivity.,)<

# %%
df_non_term_toekn_info = pd.DataFrame(list_dic_of_sent_tag_info)

# %%
df_non_term_toekn_info['pos_spacy'].value_counts()
# Out:
# NOUN     1070
# ADP      1048
# SPACE     979
# VERB      868
# ADJ       498
# DET       407
# PUNCT     106
# ADV        84
# CCONJ      80
# PART       78
# NUM        45
# SCONJ      34
# PROPN      27
# PRON       22
# AUX        17
# X           9
# SYM         3
# Name: pos_spacy, dtype: int64

# %%
df_non_term_toekn_info['tag_spacy'].value_counts()
# Out:
# IN       1081
# _SP       979
# NN        851
# JJ        446
# DT        399
# VBZ       338
# NNS       219
# VBN       183
# VB        139
# VBG        98
# VBP        97
# CC         80
# RB         78
# -RRB-      48
# JJR        46
# CD         45
# TO         40
# ,          39
# NNP        27
# RBR        19
# MD         17
# WRB        16
# VBD        13
# -LRB-      10
# FW          9
# EX          8
# WDT         8
# PRP$        7
# JJS         6
# POS         6
# WP          5
# ''          4
# RBS         3
# ``          2
# $           2
# PRP         2
# HYPH        2
# RP          1
# SYM         1
# NFP         1
# Name: tag_spacy, dtype: int64

# %%
df_non_term_toekn_info.groupby(['pos_spacy', 'tag_spacy']).size()
# Out:
# pos_spacy  tag_spacy
# ADJ        JJ            446
#            JJR            46
#            JJS             6
# ADP        IN           1047
#            RP              1
# ADV        RB             46
#            RBR            19
#            RBS             3
#            WRB            16
# AUX        MD             17
# CCONJ      CC             80
# DET        DT            399
#            WDT             8
# NOUN       NN            851
#            NNS           219
# NUM        CD             45
# PART       POS             6
#            RB             32
#            TO             40
# PRON       EX              8
#            PRP             2
#            PRP$            7
#            WP              5
# PROPN      NNP            27
# PUNCT      ''              4
#            ,              39
#            -LRB-          10
#            -RRB-          48
#            HYPH            2
#            NFP             1
#            ``              2
# SCONJ      IN             34
# SPACE      _SP           979
# SYM        $               2
#            SYM             1
# VERB       VB            139
#            VBD            13
#            VBG            98
#            VBN           183
#            VBP            97
#            VBZ           338
# X          FW              9
# dtype: int64

# %% [markdown]
# ## Debug

# %%
# !conda env list

# %%
# !/home/computeruser/anaconda3/envs/scifact/bin/pip install pattern

# %%
# !/home/computeruser/anaconda3/envs/scifact/bin/pip install --no-binary :all: nmslib

# %%
# !conda install pattern
