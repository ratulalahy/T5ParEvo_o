# %% [markdown]
# ## Import

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import time
import os
import argparse
from subprocess import call


import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
tqdm.pandas()

from IPython.display import display, Markdown, Latex, HTML

import torch

from transformers import GPT2Tokenizer
from transformers import AutoModelForSequenceClassification, AutoTokenizer


from verisci.covid import AbstractRetriever, RationaleSelector, LabelPredictor
from verisci.evaluate.lib.data import GoldDataset
#import wandb

# %%
from ipymarkup import show_span_box_markup
from ipymarkup.palette import palette, BLUE, RED, GREEN

# %%
loc_df_scispacy_sentence_word_unq_ner_abr_filtered ='../../dfs_generated/linguistic/df_scispacy_sentence_word_unq_ner_abr_filtered.pkl'

# %% [markdown]
# ## Scifact

# %% [markdown]
# ### Load Data

# %%
loc_corpus = '../../data/scifact/corpus.jsonl'
loc_claim_train = '../../data/scifact/claims_train.jsonl'
loc_claim_test = '../../data/scifact/claims_test.jsonl'
loc_claim_dev = '../../data/scifact/claims_dev.jsonl'

# %%
from verisci.evaluate.lib.data import GoldDataset

# %%
def get_claim_label_from_jsonl(dataset_jsonl):
    claim_label_list_train = []


    for cur_claim in dataset_jsonl:
        claim_txt = cur_claim.claim

        for doc_id, evidence in cur_claim.evidence.items():

            ev_doc = cur_claim.release.corpus.get_document(doc_id)

            claim_label = evidence.label.name

            tmp_dic = {"claim" : claim_txt, "label" : claim_label}

            claim_label_list_train.append(tmp_dic)
    return claim_label_list_train

# %%
def get_claim_label_evidence_from_jsonl(dataset_jsonl, source):
    claim_label_list_train = []


    for cur_claim in dataset_jsonl:
        claim_txt = cur_claim.claim

        for doc_id, evidence in cur_claim.evidence.items():

            ev_doc = cur_claim.release.corpus.get_document(doc_id)

            claim_label = evidence.label.name
            
            list_rationales = []
            for i, sents in enumerate(evidence.rationales):
                list_rationales = [sent for i, sent in enumerate(ev_doc.sentences) if i in sents]

            tmp_dic = {"claim" : claim_txt, "label" : claim_label, "list_rationales" :list_rationales, "source" :source}

            claim_label_list_train.append(tmp_dic)
    return claim_label_list_train

# %%
ds_train = GoldDataset(loc_corpus, loc_claim_train)
# claim_train = ds_train.get_claim(39)
# claim_train.pretty_print()
dic_train = get_claim_label_evidence_from_jsonl(ds_train, source = "train")

# %%
ds_valid = GoldDataset(loc_corpus, loc_claim_dev)
# claim_valid = ds_valid.get_claim(42)
# claim_valid.pretty_print()
dic_valid = get_claim_label_evidence_from_jsonl(ds_valid, source = "dev")

# %%
df_claim_evid_label = pd.concat([pd.DataFrame(dic_train), pd.DataFrame(dic_valid)], ignore_index=True)

df_claim_evid_label
# Out:
#                                                  claim     label  \
# 0    1 in 5 million in UK have abnormal PrP positiv...   REFUTES
# 1    32% of liver transplantation programs required...  SUPPORTS
# 2    40mg/day dosage of folic acid and 2mg/day dosa...  SUPPORTS
# 3    76-85% of people with severe mental disorder r...  SUPPORTS
# 4    A T helper 2 cell (Th2) environment impedes di...   REFUTES
# ..                                                 ...       ...
# 768  Women with a higher birth weight are more like...  SUPPORTS
# 769  Women with a higher birth weight are more like...  SUPPORTS
# 770  aPKCz causes tumour enhancement by affecting g...   REFUTES
# 771   cSMAC formation enhances weak ligand signalling.  SUPPORTS
# 772  mTORC2 regulates intracellular cysteine levels...  SUPPORTS
#
#                                        list_rationales source
# 0    [RESULTS Of the 32,441 appendix samples 16 wer...  train
# 1    [Policies requiring discontinuation of methado...  train
# 2    [CONCLUSION Treatment with high doses of folic...  train
# 3    [Although disorder severity was correlated wit...  train
# 4    [Thus, in Lyn(-/-) mice, basophils and IgE aut...  train
# ..                                                 ...    ...
# 768  [Increased risk of breast cancer was noted wit...    dev
# 769  [RESULTS We found that heavier birth weights w...    dev
# 770  [Taken together, this demonstrates that PKCζ i...    dev
# 771  [This conclusion was supported by experiments ...    dev
# 772  [mTORC2 phosphorylates serine 26 at the cytoso...    dev
#
# [773 rows x 4 columns]

# %%
HTML(df_claim_evid_label[['claim']].to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>claim</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1 in 5 million in UK have abnormal PrP positivity.</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>32% of liver transplantation programs required patients to discontinue methadone treatment in 2001.</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>40mg/day dosage of folic acid and 2mg/day dosage of vitamin B12 does not affect chronic kidney disease (CKD) progression.</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>76-85% of people with severe mental disorder receive no treatment in low and middle income countries.</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>A T helper 2 cell (Th2) environment impedes disease development in patients with systemic lupus erythematosus (SLE).</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>A breast cancer patient's capacity to metabolize tamoxifen influences treatment outcome.</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>A country's Vaccine Alliance (GAVI) eligibility is not indictivate of accelerated adoption of the Hub vaccine.</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>A deficiency of folate increases blood levels of homocysteine.</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>A diminished ovarian reserve does not solely indicate infertility in an a priori non-infertile population.</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>A diminished ovarian reserve is a very strong indicator of infertility, even in an a priori non-infertile population.</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>A high microerythrocyte count protects against severe anemia in homozygous alpha (+)- thalassemia trait subjects.</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>A mutation in HNF4A leads to an increased risk of developing diabetes by the age of 14 years.</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>A single nucleotide variant the gene DGKK is strongly associated with increased risk of hypospadias.</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>A strong bias in the phage genome locations where the spacers were derived has been observed in many CRISPR subtypes that confer the immunity to phage.</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>ALDH1 expression is associated with poorer prognosis for breast cancer primary tumors.</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>AMP-activated protein kinase (AMPK) activation reduces inflammation-related fibrosis in the lungs.</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>APOE4 expression in iPSC-derived neurons results in decreased tau phosphorylation.</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>ART has no effect on the infectiveness of HIV-positive people.</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>ART substantially reduces infectiveness of HIV-positive people.</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Activated Cdk5 phosphorylates the ATM protein in response to DNA damage.</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Activated Cdk5 regulates DNA damage-induced neuronal death.</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Activation of PPM1D enhances p53 function.</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Activation of PPM1D enhances p53 function.</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Activation of the Rac1 homolog CED-10 kills viable cells in SRGP-1 mutant Caenorhabditis elegans.</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>Active Ly49Q induces neutrophil polarization.</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>Active Ly49Q prevents neutrophil polarization.</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>Active caspase-11 participate in regulating phagosome-lysosome fusion.</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>Active caspase-11 protein promotes pyroptosis.</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>Adult tissue-resident macrophages are seeded before birth.</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>Adult tissue-resident macrophages are seeded before birth.</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>Adult tissue-resident macrophages are seeded before birth.</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>Adult tissue-resident macrophages are seeded before birth.</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>Adult tissue-resident macrophages possess a self-renewing capacity.</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>Aggravated inflammation is dependent on NLRP3 inflammasome activation.</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>Alirocumab treatment reduces apo(a) fractional clearance rate.</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>Allogeneic mechanical circulatory support is not as effective as autologous mechanical circulatory support for treating acute myocardial infarction.</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>Alteration of origin firing causes changes in termination zones of Okazaki fragments.</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>Ambulatory blood pressure monitoring is inaccurate at diagnosing hypertension.</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>Ambulatory blood pressure monitoring is inaccurate at diagnosing hypertension.</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>Amitriptyline is an effective treatment for chronic tension-type headaches.</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>Amitriptyline is an effective treatment for chronic tension-type headaches.</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>Amitriptyline is an effective treatment for chronic tension-type headaches.</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>An M2-like phenotype in brown adipose tissue macrophages is quickly induced by cold exposure.</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>Androgenetic haploid mouse embryonic stem cells (ESCs) can be derived and genetically manipulated in vitro.</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>Angiotensin converting enzyme inhibitors are associated with decreased risk for functional renal insufficiency.</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>Anthrax spores are very difficult to dispose once they are dispersed.</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>Anthrax spores remain deadly until affected areas are decontaminated.</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>Antidepressants increase the severity of migraines.</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>Antidepressants reduce the severity of migraines.</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>Antimicrobial agents are less effective due to the pressure of antimicrobial usage.</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>Antimicrobial agents are more effective due to the pressure of antimicrobial usage.</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>Antiretroviral therapy increases rates of tuberculosis across a broad range of CD4 strata.</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>Asymptomatic visual impairment screening in elderly populations leads to improved vision.</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>Autologous transplantation of mesenchymal stem cells has better graft function than induction therapy with anti-interleukin-2 receptor antibodies.</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>Autophagy deficiency in the liver increases vulnerability to insulin resistance.</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>B cells go though plasmablast differentiation and antibody production by continuous expression of EBI2.</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>BCL-2 activation antagonizes the apoptotic effects of c-Myc.</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>BCL-2 promotes the apoptotic effects of c-Myc.</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>BLM gene encodes RecQ-class DNA helic

# %% [markdown]
# ## Transformer

# %%
df_claim_evid_label.iloc[638]['claim']
# Out:
# 'High-sensitivity cardiac troponin T (HSCT-T) dosage may not be diagnostic if the onset of symptoms occurs less than 3 hours before acute myocardial injury (AMI).'

# %%
from transformers import BertTokenizer, BertForTokenClassification
from temporal_taggers.tagger import BERTWithDateLayerTokenClassification, BertWithCRF, DateTokenizer
from temporal_taggers.evaluation import merge_tokens, insert_tags_in_raw_text

# %%
tokenizer_temporal_sat_bert = AutoTokenizer.from_pretrained("satyaalmasian/temporal_tagger_BERT_tokenclassifier", use_fast=False)
model_temporal_sat_bert = BertForTokenClassification.from_pretrained("satyaalmasian/temporal_tagger_BERT_tokenclassifier")

# %%
#processed_temporal_sat_bert = tokenizer_temporal_sat_bert.tokenize(df_claim_evid_label.iloc[638]['claim'])

# %%
list_all_time_ents = []
for indx_, cur_row in tqdm(df_claim_evid_label.iterrows(), total=len(df_claim_evid_label)):

    try:
        annotation_id_temporal_sat_bert = 1
        id2label_temporal_sat_bert = {v: k for k, v in model_temporal_sat_bert.config.label2id.items()}


        processed_temporal_sat_bert = tokenizer_temporal_sat_bert(cur_row['claim'], return_tensors="pt")

        result_temporal_sat_bert = model_temporal_sat_bert(**processed_temporal_sat_bert)
        classification_temporal_sat_bert= result_temporal_sat_bert[0]


        result_temporal_sat_bert = model_temporal_sat_bert(**processed_temporal_sat_bert)
        classification_temporal_sat_bert = torch.argmax(result_temporal_sat_bert[0], dim=2)

        merged_tokens_temporal_sat_bert = merge_tokens(processed_temporal_sat_bert["input_ids"][0], classification_temporal_sat_bert[0], id2label_temporal_sat_bert, tokenizer_temporal_sat_bert)

        cur_time_ents = [x_ for x_ in merged_tokens_temporal_sat_bert if x_[1] != 'O']
        list_all_time_ents.append({'claim' : cur_row['claim'], 'time_ents' : cur_time_ents})
    except Exception as e:
        pass
# merged_tokens = merge_tokens(processed_text["input_ids"][0], classification[0], id2label, text_tokenizer)
# annotated_text, annotation_id = insert_tags_in_raw_text(input_text, merged_tokens, annotation_id)
# Out:
# 100%|██████████| 773/773 [01:20<00:00,  9.58it/s]

# %%
[print(x_) for x_ in merged_tokens_temporal_sat_bert if x_[1] != 'O']
# Out:
# []

# %%
df_claim_time_ent_list = pd.DataFrame(list_all_time_ents)

# %% [raw]
# df_claim_time_ent_list

# %%
HTML(df_claim_time_ent_list[df_claim_time_ent_list['time_ents'].map(lambda d: len(d)) > 0].reset_index(drop = True).to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>claim</th>
#       <th>time_ents</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>32% of liver transplantation programs required patients to discontinue methadone treatment in 2001.</td>
#       <td>[(2001, DATE)]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>40mg/day dosage of folic acid and 2mg/day dosage of vitamin B12 does not affect chronic kidney disease (CKD) progression.</td>
#       <td>[(day, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>A mutation in HNF4A leads to an increased risk of developing diabetes by the age of 14 years.</td>
#       <td>[(the, DURATION), (age, DURATION), (14, DURATION), (years, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Combination nicotine replacement therapies with varenicline or bupropion are more effective after 12 weeks of reatment compared to varenicline monotherapy.</td>
#       <td>[(12, DURATION), (weeks, DURATION), (of, DURATION), (reatment, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Commelina yellow mottle virus' (ComYMV) genome consists of 2140 baise pairs.</td>
#       <td>[(2140, DATE)]</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Improvements in OER catalysts show stable activity over several hundred hours.</td>
#       <td>[(several, DURATION), (hundred, DURATION), (hours, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>In rhesus macaques, daily subcutaneous injections of tenofovir protects against rectally transmitted simian-human immunodeficiency virus.</td>
#       <td>[(daily, SET)]</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>In young and middle-aged adults, current or remote uses of ADHD medications increase the risk of serious cardiovascular events.</td>
#       <td>[(current, DATE)]</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Incidence of heart failure increased by 10% in women since 1979.</td>
#       <td>[(1979, DATE)]</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Incidence of sepsis has fallen substantially from 2009 to 2014.</td>
#       <td>[(2009, DATE), (2014, DATE)]</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Individuals with Alzheimers who participate in six months of physical activity improve cognitive function for up to 18 months.</td>
#       <td>[(six, DURATION), (months, DURATION), (up, DURATION), (to, DURATION), (18, DURATION), (months, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Long chain polyunsaturated fatty acids supplementation is associated with lower rates of atopic eczema at 1 year.</td>
#       <td>[(1, DURATION), (year, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Pediatric SCD patients with vaso-occlusive crisis show increased morphine use after breathing 80 ppm iNO for 4 hours.</td>
#       <td>[(4, DURATION), (hours, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Pioneer factor OCT3/4 interacts with major chromatin remodeling factors.</td>
#       <td>[(oct3, DATE)]</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Pioneer factor OCT3/4 interacts with major chromatin remodeling factors.</td>
#       <td>[(oct3, DATE)]</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Sepsis related mortality has remained stable between 2009-2014.</td>
#       <td>[(2009, DATE), (2014, DATE)]</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Sepsis related mortality has risen from 2009 to 2014.</td>
#       <td>[(2009, DATE), (2014, DATE)]</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Students who perform poorly in the early years of medical school are at increased risk for professional misconduct later in their careers.</td>
#       <td>[(the, DURATION), (early, DURATION), (years, DURATION), (of, DURATION), (medical, DURATION), (school, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Students who perform poorly in the early years of medical school are less likely to commit professional misconduct later in their careers.</td>
#       <td>[(the, DURATION), (early, DURATION), (years, DURATION), (of, DURATION), (medical, DURATION), (school, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>There is no known interaction between Pioneer factor OCT3/4 and major chromatin remodeling factors.</td>
#       <td>[(oct3, DATE)]</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>There is no known interaction between Pioneer factor OCT3/4 and major chromatin remodeling factors.</td>
#       <td>[(oct3, DATE)]</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>There was an estimated 30 million cases of pneumonia in young children worldwide in 2010.</td>
#       <td>[(2010, DATE)]</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Varenicline monotherapy is more effective after 26 weeks of treatment compared to combination nicotine replacement therapies with varenicline or bupropion.</td>
#       <td>[(26, DURATION), (weeks, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>1/2000 in UK have abnormal PrP positivity.</td>
#       <td>[(2000, DATE)]</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>Combination nicotine replacement therapies with varenicline or bupropion lead to significantly higher long-term abstinence rates at 52 weeks than varenicline monotherapy.</td>
#       <td>[(52, DURATION), (weeks, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>High-sensitivity cardiac troponin T (HSCT-T) dosage may not be diagnostic if the onset of symptoms occurs less than 3 hours before acute myocardial injury (AMI).</td>
#       <td>[(less, DURATION), (than, DURATION), (3, DURATION), (hours, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>In young and middle-aged adults, current or remote uses of ADHD medications do not increase the risk of serious cardiovascular events.</td>
#       <td>[(current, DATE)]</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>Incidence of heart failure decreased by 10% in women since 1979.</td>
#       <td>[(1979, DATE)]</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>Participating in six months of physical activity improves cognitive functioning.</td>
#       <td>[(six, DURATION), (months, DURATION), (of, DURATION), (physical, DURATION), (activity, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>Varenicline monotherapy is more effective after 12 weeks of treatment compared to combination nicotine replacement therapies with varenicline or bupropion.</td>
#       <td>[(12, DURATION), (weeks, DURATION)]</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_claim_time_ent_list[df_claim_time_ent_list['time_ents'].map(lambda d: len(d)) > 0].to_csv('time_ents.csv')

# %% [markdown]
# ## sutime
# https://github.com/FraBle/python-sutime

# %%
import json
from sutime import SUTime


test_case = 'I need a desk for tomorrow from 2pm to 3pm'
sutime = SUTime(mark_time_ranges=True, include_range=True)
print(json.dumps(sutime.parse(test_case), sort_keys=True, indent=4))
# Out:
# [
#     {
#         "end": 26,
#         "start": 18,
#         "text": "tomorrow",
#         "timex-value": "2022-02-19",
#         "type": "DATE",
#         "value": "2022-02-19"
#     },
#     {
#         "end": 42,
#         "start": 27,
#         "text": "from 2pm to 3pm",
#         "type": "DURATION",
#         "value": {
#             "begin": "T14:00",
#             "end": "T15:00"
#         }
#     }
# ]

# %% [raw]
# list_all_time_ents = []
# for indx_, cur_row in tqdm(df_claim_evid_label.iterrows(), total = len(df_claim_evid_label)):
#     cur_claim_su_time = sutime.parse(cur_row['claim'])
#     for cur_su_time_element in cur_claim_su_time:
#         cur_su_time_element['org_claim'] = cur_row['claim']
#         list_all_time_ents.append(cur_su_time_element)

# %%
list_all_temporal_ents_sutime = []
for indx_, cur_row in tqdm(df_claim_evid_label.iterrows(), total = len(df_claim_evid_label)):
    cur_claim_su_time = sutime.parse(cur_row['claim'])
    list_cur_claim_imarkup_spans = []
    for cur_su_time_ent in cur_claim_su_time:
        tpl_imarkup_span = (cur_su_time_ent['start'], cur_su_time_ent['end'], cur_su_time_ent['type'])
        list_cur_claim_imarkup_spans.append(tpl_imarkup_span)
    list_all_temporal_ents_sutime.append({'claim' : cur_row['claim'], 
                                          'su_time_ents' : cur_claim_su_time, 
                                         'imarkup_span' :list_cur_claim_imarkup_spans})
# Out:
# 100%|██████████| 773/773 [00:42<00:00, 18.09it/s]

# %%
df_all_claim_temporal_su_time = pd.DataFrame(list_all_temporal_ents_sutime)

# %%
df_all_claim_temporal_su_time_valids = df_all_claim_temporal_su_time[df_all_claim_temporal_su_time['su_time_ents'].map(lambda d: len(d)) > 0].reset_index(drop = True)

# %%
for cur_indx, cur_row in df_all_claim_temporal_su_time_valids.iterrows():
    show_span_box_markup(cur_row['claim'], cur_row['imarkup_span'])
# Out:
# <div class="tex2jax_ignore" style="white-space: pre-wrap">32% of liver transplantation programs required patients to discontinue methadone treatment in <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">2001<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">DATE</span></span>.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">40mg/<span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">day<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">DURATION</span></span> dosage of folic acid and 2mg/<span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">day<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">DURATION</span></span> dosage of vitamin B12 does not affect chronic kidney disease (CKD) progression.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">A mutation in HNF4A leads to an increased risk of developing diabetes by the age of <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">14 years<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">DURATION</span></span>.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Anthrax spores are very difficult to dispose <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">once<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">DATE</span></span> they are dispersed.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Combination nicotine replacement therapies with varenicline or bupropion are more effective after <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">12 weeks<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">DURATION</span></span> of reatment compared to varenicline monotherapy.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Commelina yellow mottle virus&#x27; (ComYMV) genome consists of <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">2140<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">DATE</span></span> baise pairs.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Improvements in OER catalysts show stable activity over several <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">hundred hours<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">DURATION</span></span>.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">In rhesus macaques, <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">daily<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">SET</span></span> subcutaneous injections of tenofovir protects against rectally transmitted simian-human immunodeficiency virus.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">In young and middle-aged adults, <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">current<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">DATE</span></span> or remote uses of ADHD medications increase the risk of serious cardiovascular events.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Incidence of heart failure increased by 10% in women since <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">1979<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">DATE</span></span>.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Incidence of sepsis has fallen substantially <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">from 2009 to 2014<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">DURATION</span></span>.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Individuals with Alzheimers who participate in <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">six months<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">DURATION</span></span> of physical activity improve cognitive function for <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">up to 18 months<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">DURATION</span></span>.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Long chain polyunsaturated fatty acids supplementation is associated with lower rates of atopic eczema at <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">1 year<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">DURATION</span></span>.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Nonhypertensive people who are <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">55 years old<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">DURATION</span></span> have a 90% chance of developing hypertension during their lifetime.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Pediatric SCD patients with vaso-occlusive crisis show increased morphine use after breathing 80 ppm iNO for <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">4 hours<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">DURATION</span></span>.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Sepsis related mortality has remained stable between <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">2009-2014<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">DURATION</span></span>.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Sepsis related mortality has risen <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">from 2009 to 2014<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">DURATION</span></span>.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Students who perform poorly in <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">the early years<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">DURATION</span></span> of medical school are at increased risk for professional misconduct later in their careers.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Students who perform poorly in <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">the early years<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">DURATION</span></span> of medical school are less likely to commit professional misconduct later in their careers.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">There was an estimated 30 million cases of pneumonia in young children worldwide in <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">2010<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">DATE</span></span>.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Varenicline monotherapy is more effective after <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">26 weeks<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">DURATION</span></span> of treatment compared to combination nicotine replacement therapies with varenicline or bupropion.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Combination nicotine replacement therapies with varenicline or bupropion lead to significantly higher long-term abstinence rates at <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">52 weeks<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">DURATION</span></span> than varenicline monotherapy.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Free histones are degraded by a Rad53-dependent mechanism <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">once<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">DATE</span></span> DNA has been replicated.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">High-sensitivity cardiac troponin T (HSCT-T) dosage may not be diagnostic if the onset of symptoms occurs <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">less than 3 hours<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">DURATION</span></span> before acute myocardial injury (AMI).</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">In young and middle-aged adults, <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">current<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">DATE</span></span> or remote uses of ADHD medications do not increase the risk of serious cardiovascular events.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Incidence of heart failure decreased by 10% in women since <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">1979<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">DATE</span></span>.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Participating in <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">six months<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">DURATION</span></span> of physical activity improves cognitive functioning.</div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Varenicline monotherapy is more effective after <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">12 weeks<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">DURATION</span></span> of treatment compared to combination nicotine replacement therapies with varenicline or bupropion.</div>

# %%
HTML(df_all_claim_temporal_su_time_valids.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>claim</th>
#       <th>su_time_ents</th>
#       <th>imarkup_span</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>32% of liver transplantation programs required patients to discontinue methadone treatment in 2001.</td>
#       <td>[{'timex-value': '2001', 'start': 94, 'end': 98, 'text': '2001', 'type': 'DATE', 'value': '2001'}]</td>
#       <td>[(94, 98, DATE)]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>40mg/day dosage of folic acid and 2mg/day dosage of vitamin B12 does not affect chronic kidney disease (CKD) progression.</td>
#       <td>[{'timex-value': 'P1D', 'start': 5, 'end': 8, 'text': 'day', 'type': 'DURATION', 'value': 'P1D'}, {'timex-value': 'P1D', 'start': 38, 'end': 41, 'text': 'day', 'type': 'DURATION', 'value': 'P1D'}]</td>
#       <td>[(5, 8, DURATION), (38, 41, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>A mutation in HNF4A leads to an increased risk of developing diabetes by the age of 14 years.</td>
#       <td>[{'timex-value': 'P14Y', 'start': 84, 'end': 92, 'text': '14 years', 'type': 'DURATION', 'value': 'P14Y'}]</td>
#       <td>[(84, 92, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Anthrax spores are very difficult to dispose once they are dispersed.</td>
#       <td>[{'timex-value': 'PAST_REF', 'start': 45, 'end': 49, 'text': 'once', 'type': 'DATE', 'value': 'PAST_REF'}]</td>
#       <td>[(45, 49, DATE)]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Combination nicotine replacement therapies with varenicline or bupropion are more effective after 12 weeks of reatment compared to varenicline monotherapy.</td>
#       <td>[{'timex-value': 'P12W', 'start': 98, 'end': 106, 'text': '12 weeks', 'type': 'DURATION', 'value': 'P12W'}]</td>
#       <td>[(98, 106, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Commelina yellow mottle virus' (ComYMV) genome consists of 2140 baise pairs.</td>
#       <td>[{'timex-value': '2140', 'start': 59, 'end': 63, 'text': '2140', 'type': 'DATE', 'value': '2140'}]</td>
#       <td>[(59, 63, DATE)]</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Improvements in OER catalysts show stable activity over several hundred hours.</td>
#       <td>[{'timex-value': 'PT100H', 'start': 64, 'end': 77, 'text': 'hundred hours', 'type': 'DURATION', 'value': 'PT100H'}]</td>
#       <td>[(64, 77, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>In rhesus macaques, daily subcutaneous injections of tenofovir protects against rectally transmitted simian-human immunodeficiency virus.</td>
#       <td>[{'timex-value': 'P1D', 'start': 20, 'end': 25, 'text': 'daily', 'type': 'SET', 'value': 'P1D'}]</td>
#       <td>[(20, 25, SET)]</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>In young and middle-aged adults, current or remote uses of ADHD medications increase the risk of serious cardiovascular events.</td>
#       <td>[{'timex-value': 'PRESENT_REF', 'start': 33, 'end': 40, 'text': 'current', 'type': 'DATE', 'value': 'PRESENT_REF'}]</td>
#       <td>[(33, 40, DATE)]</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Incidence of heart failure increased by 10% in women since 1979.</td>
#       <td>[{'timex-value': '1979', 'start': 59, 'end': 63, 'text': '1979', 'type': 'DATE', 'value': '1979'}]</td>
#       <td>[(59, 63, DATE)]</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Incidence of sepsis has fallen substantially from 2009 to 2014.</td>
#       <td>[{'start': 45, 'end': 62, 'text': 'from 2009 to 2014', 'type': 'DURATION', 'value': {'end': '2014', 'begin': '2009'}}]</td>
#       <td>[(45, 62, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Individuals with Alzheimers who participate in six months of physical activity improve cognitive function for up to 18 months.</td>
#       <td>[{'timex-value': 'P6M', 'start': 47, 'end': 57, 'text': 'six months', 'type': 'DURATION', 'value': 'P6M'}, {'timex-value': 'P18M', 'start': 110, 'end': 125, 'text': 'up to 18 months', 'type': 'DURATION', 'value': 'P18M'}]</td>
#       <td>[(47, 57, DURATION), (110, 125, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Long chain polyunsaturated fatty acids supplementation is associated with lower rates of atopic eczema at 1 year.</td>
#       <td>[{'timex-value': 'P1Y', 'start': 106, 'end': 112, 'text': '1 year', 'type': 'DURATION', 'value': 'P1Y'}]</td>
#       <td>[(106, 112, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Nonhypertensive people who are 55 years old have a 90% chance of developing hypertension during their lifetime.</td>
#       <td>[{'timex-value': 'P55Y', 'start': 31, 'end': 43, 'text': '55 years old', 'type': 'DURATION', 'value': 'P55Y'}]</td>
#       <td>[(31, 43, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Pediatric SCD patients with vaso-occlusive crisis show increased morphine use after breathing 80 ppm iNO for 4 hours.</td>
#       <td>[{'timex-value': 'PT4H', 'start': 109, 'end': 116, 'text': '4 hours', 'type': 'DURATION', 'value': 'PT4H'}]</td>
#       <td>[(109, 116, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Sepsis related mortality has remained stable between 2009-2014.</td>
#       <td>[{'start': 53, 'end': 62, 'text': '2009-2014', 'type': 'DURATION', 'value': {'end': '2014', 'begin': '2009'}}]</td>
#       <td>[(53, 62, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Sepsis related mortality has risen from 2009 to 2014.</td>
#       <td>[{'start': 35, 'end': 52, 'text': 'from 2009 to 2014', 'type': 'DURATION', 'value': {'end': '2014', 'begin': '2009'}}]</td>
#       <td>[(35, 52, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Students who perform poorly in the early years of medical school are at increased risk for professional misconduct later in their careers.</td>
#       <td>[{'timex-value': 'PXY', 'start': 31, 'end': 46, 'text': 'the early years', 'type': 'DURATION', 'value': 'PXY'}]</td>
#       <td>[(31, 46, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Students who perform poorly in the early years of medical school are less likely to commit professional misconduct later in their careers.</td>
#       <td>[{'timex-value': 'PXY', 'start': 31, 'end': 46, 'text': 'the early years', 'type': 'DURATION', 'value': 'PXY'}]</td>
#       <td>[(31, 46, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>There was an estimated 30 million cases of pneumonia in young children worldwide in 2010.</td>
#       <td>[{'timex-value': '2010', 'start': 84, 'end': 88, 'text': '2010', 'type': 'DATE', 'value': '2010'}]</td>
#       <td>[(84, 88, DATE)]</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Varenicline monotherapy is more effective after 26 weeks of treatment compared to combination nicotine replacement therapies with varenicline or bupropion.</td>
#       <td>[{'timex-value': 'P26W', 'start': 48, 'end': 56, 'text': '26 weeks', 'type': 'DURATION', 'value': 'P26W'}]</td>
#       <td>[(48, 56, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Combination nicotine replacement therapies with varenicline or bupropion lead to significantly higher long-term abstinence rates at 52 weeks than varenicline monotherapy.</td>
#       <td>[{'timex-value': 'P52W', 'start': 132, 'end': 140, 'text': '52 weeks', 'type': 'DURATION', 'value': 'P52W'}]</td>
#       <td>[(132, 140, DURATION)]</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Free histones are degraded by a Rad53-dependent mechanism once DNA has been replicated.</td>
#       <td>[{'timex-value': 'PAST_REF', 'start': 58, 'end': 62, 'text': 'once', 'type': 'DATE', 'value': 'PAST_REF'}]</td>
#       <td>[(58, 62, DATE)]</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>High-sensitivity cardiac troponin T (HSCT-T) dosage may not be diagnostic if the onset of symptoms occurs less than 3 hours before acute myocardial injury (AMI).</td>
#       <td>[{'timex-value': 'PT3H', 'start': 106, 'end': 123, 'tex

# %% [markdown]
# ## Libraries

# %% [markdown]
# ### Medical
# - https://github.com/ymnliu/MedTimer
# - https://bmcmedinformdecismak.biomedcentral.com/articles/10.1186/s12911-020-01208-9

# %% [markdown]
# ## Debug

# %%
# !conda env list
# Out:
# # conda environments:
# #
#                          /home/qudratealahyratu/anaconda3
#                          /home/qudratealahyratu/anaconda3/envs/common
#                          /home/qudratealahyratu/anaconda3/envs/gym_gpu
#                          /home/qudratealahyratu/anaconda3/envs/gym_tf_gpu
#                          /home/qudratealahyratu/anaconda3/envs/knowledge_graph
# base                  *  /home/qudratealahyratu/anaconda3/envs/scifact
#                          /home/qudratealahyratu/anaconda3/envs/scifact2

# %%
# !/home/qudratealahyratu/anaconda3/envs/scifact/bin/pip install sutime
# Out:
# Collecting sutime
#   Downloading sutime-1.0.1-py3-none-any.whl (28 kB)
# Collecting JPype1<2.0.0,>=1.1.2
#   Downloading JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 4.9 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions in /home/qudratealahyratu/anaconda3/envs/scifact/lib/python3.7/site-packages (from JPype1<2.0.0,>=1.1.2->sutime) (3.10.0.2)
# Installing collected packages: JPype1, sutime
# Successfully installed JPype1-1.3.0 sutime-1.0.1

# %% [raw]
# !mvn dependency:copy-dependencies -DoutputDirectory=./jars -f $(python3 -c 'import importlib; import pathlib; print(pathlib.Path(importlib.util.find_spec("sutime").origin).parent / "pom.xml")')
